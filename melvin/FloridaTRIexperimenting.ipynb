# %%
# %pylab inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
            
FL1997 = pd.read_csv("data\TRI_1997_FL.csv")
FL1998 = pd.read_csv("data\TRI_1998_FL.csv")
FL1999 = pd.read_csv("data\TRI_1999_FL.csv")
FL2000 = pd.read_csv("data\TRI_2000_FL.csv")
FL2001 = pd.read_csv("data\TRI_2001_FL.csv")

data_97_01 =[FL1997,FL1998,FL1999,FL2000,FL2001]
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
clear_air_chem = [num[['YEAR','FACILITY_NAME','CHEMICAL','CLEAR_AIR_ACT_CHEMICAL']] for num in data_97_01]

# %%
clear1997 = clear_air_chem[0][clear_air_chem[0]['CLEAR_AIR_ACT_CHEMICAL']== 'YES']
clear1998 = clear_air_chem[1][clear_air_chem[1]['CLEAR_AIR_ACT_CHEMICAL']== 'YES']
clear1999 = clear_air_chem[2][clear_air_chem[2]['CLEAR_AIR_ACT_CHEMICAL']== 'YES']
clear2000 = clear_air_chem[3][clear_air_chem[3]['CLEAR_AIR_ACT_CHEMICAL']== 'YES']
clear2001 = clear_air_chem[4][clear_air_chem[4]['CLEAR_AIR_ACT_CHEMICAL']== 'YES']
clear2000
# Out:
#       YEAR                                      FACILITY_NAME  \
# 3     2000            MOSAIC FERTILIZER LLC - GREEN BAY PLANT
# 5     2000     BUCKEYE TERMINALS, LLC - JACKSONVILLE TERMINAL
# 6     2000                                           WESTROCK
# 7     2000                         CD MCINTOSH JR POWER PLANT
# 9     2000                                   ARIZONA CHEMICAL
# 11    2000                                        SIVANCE LLC
# 12    2000                                        SIVANCE LLC
# 13    2000                                           WESTROCK
# 14    2000                                   ARIZONA CHEMICAL
# 15    2000                               ARGOS NEWBERRY PLANT
# 17    2000             US NAVY NAVAL AIR STATION JACKSONVILLE
# 18    2000                       SUNBELT FOREST PRODUCTS CORP
# 20    2000               STERLING FIBERS INC SANTA ROSA PLANT
# 21    2000                    CITRUS WORLD INC LAKE WALES DIV
# ...

# %%
totalrelease = [num2[['YEAR','FACILITY_NAME','CHEMICAL','TOTAL_RELEASES']] for num2 in data_97_01]
total1997 = totalrelease[0]
total1998 = totalrelease[1]
total1999 = totalrelease[2]
total2000 = totalrelease[3]
total2001 = totalrelease[4]
#top1997 = [totalrelease[0].sort_values('TOTAL_RELEASES', ascending=False)[0:10] for i in range(len(nameChemTotal))]
#topTens = [nameChemTotal[i].sort_values('TOTAL_RELEASES', ascending=False)[0:10] for i in range(len(nameChemTotal))]

# %%
CARCINOGEN = [num2[['YEAR','FACILITY_NAME','CHEMICAL','CARCINOGEN']] for num2 in data_97_01]

# %%
car1997 = CARCINOGEN[0][CARCINOGEN[0]['CARCINOGEN']== 'YES']
car1998 = CARCINOGEN[1][CARCINOGEN[1]['CARCINOGEN']== 'YES']
car1999 = CARCINOGEN[2][CARCINOGEN[2]['CARCINOGEN']== 'YES']
car2000 = CARCINOGEN[3][CARCINOGEN[3]['CARCINOGEN']== 'YES']
car2001 = CARCINOGEN[4][CARCINOGEN[4]['CARCINOGEN']== 'YES']

# %%
cartotal_release = [num3[['YEAR','FACILITY_NAME','CHEMICAL','CARCINOGEN','TOTAL_RELEASES','ON-SITE_RELEASE_TOTAL']] for num3 in data_97_01]

# %%
cartotal_release[0]
# Out:
#       YEAR                                      FACILITY_NAME  \
# 0     1997                           MERCK SHARP & DOHME CORP
# 1     1997                 BALL METAL BEVERAGE CONTAINER CORP
# 2     1997            GEORGIA-PACIFIC CONSUMER OPERATIONS LLC
# 3     1997            GEORGIA-PACIFIC CONSUMER OPERATIONS LLC
# 4     1997                   SEA RAY BOATS INC MERRITT ISLAND
# 5     1997                   SEA RAY BOATS INC MERRITT ISLAND
# 6     1997                             DELTA LABORATORIES INC
# 7     1997                                        A1 SUPERIOR
# 8     1997          PRIDE ACI SANITARY MAINTENANCE & SUPPLIES
# 9     1997  GEORGIA-PACIFIC WOOD PRODUCTS LLC OCALA I-BEAM...
# 10    1997                            TRADEMARK NITROGEN CORP
# 11    1997  PEPSI-COLA BOTTLING CO OF FT LAUDERDALE-PALM B...
# 12    1997                                    DYCO PAINTS INC
# 13    1997    OWENS CORNING INSULATING SYSTEMS LLC - LAKELAND
# ...

# %%
topthree = [cartotal_release[i].sort_values('TOTAL_RELEASES', ascending=False)[0:3] for i in range(len(cartotal_release))]

# %%
topthree[0]['TOTAL_RELEASES'].plot.bar(label='Top 3 total releases',color='red', legend=None,title='2000')

# %%
topthree[1]['TOTAL_RELEASES'].plot.bar(label='Top 3 total releases',color='green', legend=None,title='1998')
topthree[1]
# Out:
#       YEAR                                FACILITY_NAME  \
# 800   1998  ASCEND PERFORMANCE MATERIALS OPERATIONS LLC
# 1780  1998                  GULF POWER CO - PLANT CRIST
# 1609  1998                  SEMINOLE GENERATING STATION
#
#                                                CHEMICAL CARCINOGEN  \
# 800                                   NITRATE COMPOUNDS         NO
# 1780  HYDROCHLORIC ACID (1995 AND AFTER ACID AEROSOL...         NO
# 1609  SULFURIC ACID (1994 AND AFTER ACID AEROSOLS" O...         NO
#
#       TOTAL_RELEASES  ON-SITE_RELEASE_TOTAL
# 800       18260137.0               18260137
# 1780       8528268.0                8528268
# 1609       7392553.0                7392553

# %%
topthree[2]['TOTAL_RELEASES'].plot.bar(label='Top 3 total releases',color='blue', legend=None,title='1999')

# %%
topthree[3]['TOTAL_RELEASES'].plot.bar(label='Top 3 total releases',color='yellow', legend=None,title='2000')

# %%
topthree[4]['TOTAL_RELEASES'].plot.bar(label='Top 3 total releases',color='pink', legend=None,title='2001')

# %%
industrysector = [num3[['YEAR','FACILITY_NAME','CHEMICAL','CARCINOGEN','INDUSTRY_SECTOR']] for num3 in data_97_01]

# %%
industrysector[0]
# Out:
#       YEAR                                      FACILITY_NAME  \
# 0     1997                           MERCK SHARP & DOHME CORP
# 1     1997                 BALL METAL BEVERAGE CONTAINER CORP
# 2     1997            GEORGIA-PACIFIC CONSUMER OPERATIONS LLC
# 3     1997            GEORGIA-PACIFIC CONSUMER OPERATIONS LLC
# 4     1997                   SEA RAY BOATS INC MERRITT ISLAND
# 5     1997                   SEA RAY BOATS INC MERRITT ISLAND
# 6     1997                             DELTA LABORATORIES INC
# 7     1997                                        A1 SUPERIOR
# 8     1997          PRIDE ACI SANITARY MAINTENANCE & SUPPLIES
# 9     1997  GEORGIA-PACIFIC WOOD PRODUCTS LLC OCALA I-BEAM...
# 10    1997                            TRADEMARK NITROGEN CORP
# 11    1997  PEPSI-COLA BOTTLING CO OF FT LAUDERDALE-PALM B...
# 12    1997                                    DYCO PAINTS INC
# 13    1997    OWENS CORNING INSULATING SYSTEMS LLC - LAKELAND
# ...

# %%
onsite_vs_total = [num4[['YEAR','FACILITY_NAME','CHEMICAL','TOTAL_RELEASES','ON-SITE_RELEASE_TOTAL']] for num4 in data_97_01]

# %%
onst1997 = onsite_vs_total[0]
onst1998 = onsite_vs_total[1]
onst1999 = onsite_vs_total[2]
onst2000 = onsite_vs_total[3]
onst2001 = onsite_vs_total[4]

onsite_vs_total[0]['Percentage of releases on site']=onsite_vs_total[0]['ON-SITE_RELEASE_TOTAL']/onsite_vs_total[0]['TOTAL_RELEASES']
onsite_vs_total[1]['Percentage of releases on site']=onsite_vs_total[1]['ON-SITE_RELEASE_TOTAL']/onsite_vs_total[1]['TOTAL_RELEASES']
onsite_vs_total[2]['Percentage of releases on site']=onsite_vs_total[2]['ON-SITE_RELEASE_TOTAL']/onsite_vs_total[2]['TOTAL_RELEASES']
onsite_vs_total[3]['Percentage of releases on site']=onsite_vs_total[3]['ON-SITE_RELEASE_TOTAL']/onsite_vs_total[3]['TOTAL_RELEASES']
onsite_vs_total[4]['Percentage of releases on site']=onsite_vs_total[4]['ON-SITE_RELEASE_TOTAL']/onsite_vs_total[4]['TOTAL_RELEASES']
# Out:
# C:\Users\Melvin\Anaconda2\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\Melvin\Anaconda2\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Melvin\Anaconda2\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
this = [onsite_vs_total[i].sort_values('Percentage of releases on site', ascending=False)[0:55] for i in range(len(onsite_vs_total))]
this[2]
# Out:
#       YEAR                                      FACILITY_NAME  \
# 0     1999                       MOSAIC FERTILIZER LLC-BARTOW
# 1122  1999                        PCS PHOSPHATE WHITE SPRINGS
# 1141  1999                                        CHRIS CRAFT
# 1140  1999                              DOZIER & GAY PAINT CO
# 1139  1999                                       MUNTERS CORP
# 1138  1999                    MOMENTIVE PERFORMANCE MATERIALS
# 1136  1999       BP PRODUCTS NORTH AMERICA INC TAMPA TERMINAL
# 1135  1999        ASCEND PERFORMANCE MATERIALS OPERATIONS LLC
# 1134  1999           TAMPA ELECTRIC CO BIG BEND POWER STATION
# 1133  1999                                   ARIZONA CHEMICAL
# 1132  1999        UNITED STATES SUGAR CORP BRYANT SUGAR HOUSE
# 1131  1999                  SAFRAN ELECTRICAL & POWER USA LLC
# 1129  1999                             SUNBELT CHEMICALS CORP
# 1127  1999                   UNIVAR USA INC. ORLANDO FACILITY
# ...

# %%
zeroonsite1997=onsite_vs_total[0][onsite_vs_total[0]['Percentage of releases on site']== 0]
zeroonsite1998=onsite_vs_total[1][onsite_vs_total[1]['Percentage of releases on site']== 0]
zeroonsite1999=onsite_vs_total[2][onsite_vs_total[2]['Percentage of releases on site']== 0]
zeroonsite2000=onsite_vs_total[3][onsite_vs_total[3]['Percentage of releases on site']== 0]
zeroonsite2001=onsite_vs_total[4][onsite_vs_total[4]['Percentage of releases on site']== 0]

count97=len(zeroonsite1997);count98=len(zeroonsite1998);count99=len(zeroonsite1999)
count00=len(zeroonsite2000);count01=len(zeroonsite2001)

zeroonsite1997all=onsite_vs_total[0][onsite_vs_total[0]['Percentage of releases on site']== 1.0]
zeroonsite1998all=onsite_vs_total[1][onsite_vs_total[1]['Percentage of releases on site']== 1.0]
zeroonsite1999all=onsite_vs_total[2][onsite_vs_total[2]['Percentage of releases on site']== 1.0]
zeroonsite2000all=onsite_vs_total[3][onsite_vs_total[3]['Percentage of releases on site']== 1.0]
zeroonsite2001all=onsite_vs_total[4][onsite_vs_total[4]['Percentage of releases on site']== 1.0]

count97all=len(zeroonsite1997all);count98all=len(zeroonsite1998all);count99all=len(zeroonsite1999all)
count00all=len(zeroonsite2000all);count01all=len(zeroonsite2001all)
zero_on_site_release=[count97,count98,count99,count00,count01]
one_site_realease_all =[count97all,count98all,count99all,count00all,count01all]

df2 = pd.DataFrame(zero_on_site_release).plot.bar(color='red')
df2.set_xlabel("Years",fontsize=12)
df2.set_ylabel("Number of facilites",fontsize=12)
df2.set_title("Number Facilities with no onsite releases")
df2.set_xticklabels(["1997","1998","1999","2000","2001"])

print "Facility's with   0% on site releases---1997:",count97,"1998:",count98,"1999:",count99,"2000:",count00,"2001:",count01
print "Facility's with 100% on site releases---1997:",count97all,"1998:",count98all,"1999:",count99all,"2000:",count00all,"2001:",count01all
# Out:
# Facility's with   0% on site releases---1997: 46 1998: 56 1999: 57 2000: 73 2001: 114
# Facility's with 100% on site releases---1997: 770 1998: 1073 1999: 1029 2000: 1171 2001: 1257
