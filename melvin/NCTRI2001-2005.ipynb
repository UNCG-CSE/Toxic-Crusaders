# %%
# %pylab inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
            
NC2001 = pd.read_csv("data\TRI_2001_NC.csv")
NC2002 = pd.read_csv("data\TRI_2002_NC.csv")
NC2003 = pd.read_csv("data\TRI_2003_NC.csv")
NC2004 = pd.read_csv("data\TRI_2004_NC.csv")
NC2005 = pd.read_csv("data\TRI_2005_NC.csv")

NC_data =[NC2001,NC2002,NC2003,NC2004,NC2005]
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
clear_air_chem = [num[['YEAR','FACILITY_NAME','CHEMICAL','CLEAR_AIR_ACT_CHEMICAL']] for num in NC_data]

# %%
clear2001 = clear_air_chem[0][clear_air_chem[0]['CLEAR_AIR_ACT_CHEMICAL']== 'YES']
clear2002 = clear_air_chem[1][clear_air_chem[1]['CLEAR_AIR_ACT_CHEMICAL']== 'YES']
clear2003 = clear_air_chem[2][clear_air_chem[2]['CLEAR_AIR_ACT_CHEMICAL']== 'YES']
clear2004 = clear_air_chem[3][clear_air_chem[3]['CLEAR_AIR_ACT_CHEMICAL']== 'YES']
clear2005 = clear_air_chem[4][clear_air_chem[4]['CLEAR_AIR_ACT_CHEMICAL']== 'YES']
clear2001
# Out:
#       YEAR                                      FACILITY_NAME  \
# 1     2001                  MURPHY-BROWN LLC WARSAW FEED MILL
# 3     2001                               GRANGES AMERICAS INC
# 4     2001                           LINAMAR FORGING CAROLINA
# 5     2001                   TYCO ELECTRONICS CORP. BLDG. 067
# 6     2001                            AKZO NOBEL COATINGS INC
# 7     2001                              J C STEELE & SONS INC
# 8     2001                                        MERITOR INC
# 9     2001                                          BASF CORP
# 11    2001                MORTON CUSTOM PLASTICS A WILBERT CO
# 12    2001                                    APOLLO CHEMICAL
# 13    2001                            DSM PHARMACEUTICALS INC
# 14    2001                            DSM PHARMACEUTICALS INC
# 15    2001  DUKE ENERGY CAROLINAS LLC - RIVERBEND STEAM ST...
# 17    2001      HERITAGE HOME GROUP-LENOIR UPHOLSTERY COMPLEX
# ...

# %%
CARCINOGEN = [num2[['YEAR','FACILITY_NAME','CHEMICAL','CARCINOGEN']] for num2 in NC_data]

# %%
car2001 = CARCINOGEN[0][CARCINOGEN[0]['CARCINOGEN']== 'YES']
car2002 = CARCINOGEN[1][CARCINOGEN[1]['CARCINOGEN']== 'YES']
car2003 = CARCINOGEN[2][CARCINOGEN[2]['CARCINOGEN']== 'YES']
car2004 = CARCINOGEN[3][CARCINOGEN[3]['CARCINOGEN']== 'YES']
car2005 = CARCINOGEN[4][CARCINOGEN[4]['CARCINOGEN']== 'YES']

# %%
for x in car2001.columns:
    print x
# Out:
# YEAR
# FACILITY_NAME
# CHEMICAL
# CARCINOGEN

# %%
car2001.head()
pop=car2001.groupby('FACILITY_NAME').mean()
pop
# Out:
#                                                     YEAR
# FACILITY_NAME
# 3A COMPOSITES USA, INC.                             2001
# 3F CHIMICA AMERICAS, INC.                           2001
# AALLIED DIE CASTING OF NC                           2001
# ABBOTT LABS                                         2001
# ABT INC                                             2001
# ACCUMA CORP                                         2001
# ACME ELECTRIC CORP - LUMBERTON PLANT                2001
# AGFA CORP                                           2001
# AKZO NOBEL COATINGS INC                             2001
# ALBEMARLE SPORTFISHING BOATS INC                    2001
# ALBERDINGK BOLEY INC                                2001
# ALCATEL USA                                         2001
# ALCOA BADIN WORKS                                   2001
# ALEVO MANUFACTURING                                 2001
# ALLVAC - MONROE PLANT                               2001
# ...

# %%
cartotal_release = [num3[['YEAR','FACILITY_NAME','CHEMICAL','CARCINOGEN','TOTAL_RELEASES','ON-SITE_RELEASE_TOTAL']] for num3 in NC_data]

# %%
cartotal_release[4]
# Out:
#       YEAR                                      FACILITY_NAME  \
# 0     2005                                 BALDOR ELECTRIC CO
# 1     2005                                ALEVO MANUFACTURING
# 2     2005                            CNA HOLDINGS LLC-SHELBY
# 3     2005                                 GENERAL TIMBER INC
# 4     2005                                 GENERAL TIMBER INC
# 5     2005                                 GENERAL TIMBER INC
# 6     2005                           HANES DYE & FINISHING CO
# 7     2005                                              GE CO
# 8     2005                              DAIMLER TRUCKS NA LLC
# 9     2005                              DAIMLER TRUCKS NA LLC
# 10    2005        HENREDON FURNITURE INDUSTRIES-MORGANTON DIV
# 11    2005                VAUGHAN-BASSETT FURNITURE CO. ELKIN
# 12    2005                    AMPHENOL TCS MOLDING & STAMPING
# 13    2005                               NGK CERAMICS USA INC
# ...

# %%
topthree = [cartotal_release[i].sort_values('TOTAL_RELEASES', ascending=False)[0:3] for i in range(len(cartotal_release))]

# %%
topthree[0]['TOTAL_RELEASES'].plot.bar(label='Top 3 total releases',color='red', legend=None,title='2001')

# %%
topthree[1]['TOTAL_RELEASES'].plot.bar(label='Top 3 total releases',color='green', legend=None,title='2002')
topthree[1]
# Out:
#       YEAR                                      FACILITY_NAME  \
# 1044  2002  DUKE ENERGY CAROLINAS LLC - BELEWS CREEK STEAM...
# 313   2002  DUKE ENERGY PROGRESS LLC - ROXBORO STEAM ELECT...
# 2539  2002  DUKE ENERGY CAROLINAS LLC - MARSHALL STEAM STA...
#
#                                                CHEMICAL CARCINOGEN  \
# 1044  HYDROCHLORIC ACID (1995 AND AFTER ACID AEROSOL...         NO
# 313   HYDROCHLORIC ACID (1995 AND AFTER ACID AEROSOL...         NO
# 2539  HYDROCHLORIC ACID (1995 AND AFTER ACID AEROSOL...         NO
#
#       TOTAL_RELEASES  ON-SITE_RELEASE_TOTAL
# 1044      12000000.0             12000000.0
# 313       11000000.0             11000000.0
# 2539      10000000.0             10000000.0

# %%
topthree[2]['TOTAL_RELEASES'].plot.bar(label='Top 3 total releases',color='blue', legend=None,title='2003')

# %%
topthree[3]['TOTAL_RELEASES'].plot.bar(label='Top 3 total releases',color='yellow', legend=None,title='2004')

# %%
topthree[4]['TOTAL_RELEASES'].plot.bar(label='Top 3 total releases',color='pink', legend=None,title='2005')

# %%
industrysector = [num3[['YEAR','FACILITY_NAME','CHEMICAL','CARCINOGEN','INDUSTRY_SECTOR']] for num3 in NC_data]

# %%
industrysector[0]
yescar01=industrysector[0][CARCINOGEN[0]['CARCINOGEN']== 'YES']
print "Industry's associated with Carcinogen(2001)"
yescar01.groupby('INDUSTRY_SECTOR').mean()
# Out:
# Industry's associated with Carcinogen(2001)
#                                    YEAR
# INDUSTRY_SECTOR
# Beverages                          2001
# Chemical Wholesalers               2001
# Chemicals                          2001
# Computers and Electronic Products  2001
# Electric Utilities                 2001
# Electrical Equipment               2001
# Fabricated Metals                  2001
# Food                               2001
# Furniture                          2001
# Hazardous Waste                    2001
# Machinery                          2001
# Miscellaneous Manufacturing        2001
# Nonmetallic Mineral Product        2001
# Other                              2001
# Paper                              2001
# Petroleum                          2001
# Petroleum Bulk Terminals           2001
# Plastics and Rubber                2001
# Primary Metals                     2001
# Printing                           2001
# Textile Product                    2001
# ...

# %%
industrysector[0]
yescar01=industrysector[0][CARCINOGEN[0]['CARCINOGEN']== 'YES']
print "Chemicals associated with Carcinogen (2001)"
yescar01.groupby('CHEMICAL').mean()
# Out:
# Chemicals associated with Carcinogen (2001)
#                                       YEAR
# CHEMICAL
# 1,2-DICHLOROETHANE                    2001
# 1,3-BUTADIENE                         2001
# 1,3-DICHLOROPROPYLENE                 2001
# 1,4-DICHLOROBENZENE                   2001
# 1,4-DIOXANE                           2001
# 2,4-D BUTOXYETHYL ESTER               2001
# 4,4'-METHYLENEDIANILINE               2001
# ACETALDEHYDE                          2001
# ACRYLAMIDE                            2001
# ACRYLONITRILE                         2001
# ALPHA-NAPHTHYLAMINE                   2001
# ARSENIC                               2001
# ASBESTOS (FRIABLE)                    2001
# BENZENE                               2001
# BENZO(G,H,I)PERYLENE                  2001
# BERYLLIUM                             2001
# CADMIUM                               2001
# CHLOROFORM                            2001
# CHROMIUM                              2001
# ...

# %%
onsite_vs_total = [num4[['YEAR','FACILITY_NAME','CHEMICAL','TOTAL_RELEASES','ON-SITE_RELEASE_TOTAL']] for num4 in NC_data]

# %%
onst2001 = onsite_vs_total[0]
onst2002 = onsite_vs_total[1]
onst2003 = onsite_vs_total[2]
onst2004 = onsite_vs_total[3]
onst2005 = onsite_vs_total[4]

onsite_vs_total[0]['Percentage of releases on site']=onsite_vs_total[0]['ON-SITE_RELEASE_TOTAL']/onsite_vs_total[0]['TOTAL_RELEASES']
onsite_vs_total[1]['Percentage of releases on site']=onsite_vs_total[1]['ON-SITE_RELEASE_TOTAL']/onsite_vs_total[1]['TOTAL_RELEASES']
onsite_vs_total[2]['Percentage of releases on site']=onsite_vs_total[2]['ON-SITE_RELEASE_TOTAL']/onsite_vs_total[2]['TOTAL_RELEASES']
onsite_vs_total[3]['Percentage of releases on site']=onsite_vs_total[3]['ON-SITE_RELEASE_TOTAL']/onsite_vs_total[3]['TOTAL_RELEASES']
onsite_vs_total[4]['Percentage of releases on site']=onsite_vs_total[4]['ON-SITE_RELEASE_TOTAL']/onsite_vs_total[4]['TOTAL_RELEASES']
# Out:
# C:\Users\Melvin\Anaconda2\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\Melvin\Anaconda2\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Melvin\Anaconda2\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
this = [onsite_vs_total[i].sort_values('Percentage of releases on site', ascending=False)[0:20] for i in range(len(onsite_vs_total))]
this[2]
# Out:
#       YEAR                                      FACILITY_NAME  \
# 0     2003  BROYHILL FURNITURE INDUSTRIES INC VIRGINIA STR...
# 1762  2003                          ELIZABETHTOWN ENERGY, LLC
# 1780  2003                           VERTELLUS GREENSBORO LLC
# 1779  2003      HERITAGE HOME GROUP-LENOIR UPHOLSTERY COMPLEX
# 1778  2003      HERITAGE HOME GROUP-LENOIR UPHOLSTERY COMPLEX
# 1775  2003  DUKE ENERGY CAROLINAS LLC - MARSHALL STEAM STA...
# 1774  2003                              DAIMLER TRUCKS NA LLC
# 1772  2003             HOUSE OF RAEFORD FARMS INC WALLACE DIV
# 1771  2003                    RAILROAD FRICTION PRODUCTS CORP
# 1768  2003  DUKE ENERGY CAROLINAS LLC - RIVERBEND STEAM ST...
# 1767  2003                            WATTS REGULATOR WACASCO
# 1765  2003                              CAROLINA SOLVENTS INC
# 1764  2003                                       LANXESS CORP
# 1760  2003                        HICKORY WHITE CASEGOODS DIV
# ...

# %%
zeroonsite2001=onsite_vs_total[0][onsite_vs_total[0]['Percentage of releases on site']== 0]
zeroonsite2002=onsite_vs_total[1][onsite_vs_total[1]['Percentage of releases on site']== 0]
zeroonsite2003=onsite_vs_total[2][onsite_vs_total[2]['Percentage of releases on site']== 0]
zeroonsite2004=onsite_vs_total[3][onsite_vs_total[3]['Percentage of releases on site']== 0]
zeroonsite2005=onsite_vs_total[4][onsite_vs_total[4]['Percentage of releases on site']== 0]

count01=len(zeroonsite2001);count02=len(zeroonsite2002);count03=len(zeroonsite2003)
count04=len(zeroonsite2004);count05=len(zeroonsite2005)

zeroonsite2001all=onsite_vs_total[0][onsite_vs_total[0]['Percentage of releases on site']== 1.0]
zeroonsite2002all=onsite_vs_total[1][onsite_vs_total[1]['Percentage of releases on site']== 1.0]
zeroonsite2003all=onsite_vs_total[2][onsite_vs_total[2]['Percentage of releases on site']== 1.0]
zeroonsite2004all=onsite_vs_total[3][onsite_vs_total[3]['Percentage of releases on site']== 1.0]
zeroonsite2005all=onsite_vs_total[4][onsite_vs_total[4]['Percentage of releases on site']== 1.0]

count01all=len(zeroonsite2001all);count02all=len(zeroonsite2002all);count03all=len(zeroonsite2003all)
count04all=len(zeroonsite2004all);count05all=len(zeroonsite2005all)
zero_on_site_release=[count01,count02,count03,count04,count05]
one_site_release_all =[count01all,count02all,count03all,count04all,count05all]

df2 = pd.DataFrame(zero_on_site_release).plot.bar(color='red')
df2.set_xlabel("Years",fontsize=12)
df2.set_ylabel("Number of facilites",fontsize=12)
df2.set_title("Number Facilities with no onsite releases")
df2.set_xticklabels(["2001","2002","2003","2004","2005"])

df3 = pd.DataFrame(one_site_release_all).plot.bar(color='green')
df3.set_xlabel("Years",fontsize=12)
df3.set_ylabel("Number of facilites",fontsize=12)
df3.set_title("Number Facilities with 100% onsite releases")
df3.set_xticklabels(["2001","2002","2003","2004","2005"])


print "Facility's with   0% on site releases---2001:",count01,"2002:",count02,"2003:",count03,"2004:",count04,"2005:",count05
print "Facility's with 100% on site releases---2001:",count01all,"2002:",count02all,"2003:",count03all,"20004:",count04all,"2005:",count05all
# Out:
# Facility's with   0% on site releases---2001: 186 2002: 171 2003: 158 2004: 168 2005: 159
# Facility's with 100% on site releases---2001: 1524 2002: 1511 2003: 1486 20004: 1375 2005: 1318
