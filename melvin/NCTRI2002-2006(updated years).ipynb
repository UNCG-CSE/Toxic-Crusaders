# %%
# %pylab inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
            

NC2002 = pd.read_csv("data\TRI_2002_NC.csv")
NC2003 = pd.read_csv("data\TRI_2003_NC.csv")
NC2004 = pd.read_csv("data\TRI_2004_NC.csv")
NC2005 = pd.read_csv("data\TRI_2005_NC.csv")
NC2006 = pd.read_csv("data\TRI_2006_NC.csv")

NC_data =[NC2002,NC2003,NC2004,NC2005,NC2006]
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
clear_air_chem = [num[['YEAR','FACILITY_NAME','CHEMICAL','CLEAR_AIR_ACT_CHEMICAL']] for num in NC_data]

# %%
clear2002 = clear_air_chem[0][clear_air_chem[0]['CLEAR_AIR_ACT_CHEMICAL']== 'YES']
clear2003 = clear_air_chem[1][clear_air_chem[1]['CLEAR_AIR_ACT_CHEMICAL']== 'YES']
clear2004 = clear_air_chem[2][clear_air_chem[2]['CLEAR_AIR_ACT_CHEMICAL']== 'YES']
clear2005 = clear_air_chem[3][clear_air_chem[3]['CLEAR_AIR_ACT_CHEMICAL']== 'YES']
clear2006 = clear_air_chem[4][clear_air_chem[4]['CLEAR_AIR_ACT_CHEMICAL']== 'YES']
clear2002.head()
# Out:
#    YEAR                        FACILITY_NAME                 CHEMICAL  \
# 0  2002                CAMPBELL OIL & GAS CO                  BENZENE
# 1  2002              LINDSEY CAMPBELL OIL CO  METHYL TERT-BUTYL ETHER
# 2  2002              LINDSEY CAMPBELL OIL CO   XYLENE (MIXED ISOMERS)
# 3  2002  CLARCOR ENGINE MOBILE SOLUTIONS LLC                     LEAD
# 4  2002      TRINITY CONTAINERS LLC PLT 1004      MANGANESE COMPOUNDS
#
#   CLEAR_AIR_ACT_CHEMICAL
# 0                    YES
# 1                    YES
# 2                    YES
# 3                    YES
# 4                    YES

# %%
CARCINOGEN = [num2[['YEAR','FACILITY_NAME','CHEMICAL','CARCINOGEN']] for num2 in NC_data]

# %%
car2002 = CARCINOGEN[0][CARCINOGEN[0]['CARCINOGEN']== 'YES']
car2003 = CARCINOGEN[1][CARCINOGEN[1]['CARCINOGEN']== 'YES']
car2004 = CARCINOGEN[2][CARCINOGEN[2]['CARCINOGEN']== 'YES']
car2005 = CARCINOGEN[3][CARCINOGEN[3]['CARCINOGEN']== 'YES']
car2006 = CARCINOGEN[4][CARCINOGEN[4]['CARCINOGEN']== 'YES']

# %%
for x in car2002.columns:
    print x
# Out:
# YEAR
# FACILITY_NAME
# CHEMICAL
# CARCINOGEN

# %%
Facil_carcin=car2002.groupby('FACILITY_NAME').mean()
Facil_carcin['YEAR']
# Out:
# FACILITY_NAME
# 3A COMPOSITES USA, INC.                                  2002
# 3F CHIMICA AMERICAS, INC.                                2002
# A & H ART & STAINED GLASS CO INC                         2002
# AALLIED DIE CASTING OF NC                                2002
# ABT INC                                                  2002
# ACCUMA CORP                                              2002
# ACO POLYMER PRODUCTS INC                                 2002
# ADAMS AN OLDCASTLE CO - MORRISVILLE                      2002
# ADAMS AN OLDCASTLE CO-GREENSBORO                         2002
# ADAMS AN OLDCASTLE CO-LILESVILLE                         2002
# ADAMS AN OLDCASTLE COMPANY - CASTLE HAYNE                2002
# ADAMS PRODUCTS - KINSTON                                 2002
# ADAMS PRODUCTS CO - FAYETTEVILLE                         2002
# AKZO NOBEL COATINGS INC                                  2002
# ALBEMARLE SPORTFISHING BOATS INC                         2002
# ...

# %%
cartotal_release = [num3[['YEAR','FACILITY_NAME','CHEMICAL','CARCINOGEN','TOTAL_RELEASES','ON-SITE_RELEASE_TOTAL']] for num3 in NC_data]

# %%
cartotal_release[4]
# Out:
#       YEAR                                      FACILITY_NAME  \
# 0     2006                                 BRENNTAG MID-SOUTH
# 1     2006                             RF MICRO DEVICES FAB 1
# 2     2006  ENGINEERED POLYMER SOLUTIONS INC D/B/A VALSPAR...
# 3     2006                                      UNILIN US MDF
# 4     2006                           CHEMICAL SPECIALTIES LLC
# 5     2006                           CHEMICAL SPECIALTIES LLC
# 6     2006                           CHEMICAL SPECIALTIES LLC
# 7     2006                           CHEMICAL SPECIALTIES LLC
# 8     2006    MARATHON PETROLEUM CO - SELMA W OAK ST TERMINAL
# 9     2006             CENTURY FURNITURE CASEGOODS PLANT NO 1
# 10    2006                                 DRAKA ELEVATOR INC
# 11    2006                             LOUISIANA-PACIFIC CORP
# 12    2006                                      UNILIN US MDF
# 13    2006                                  TRIANGLE BRICK CO
# ...

# %%
topthree = [cartotal_release[i].sort_values('TOTAL_RELEASES', ascending=False)[0:3] for i in range(len(cartotal_release))]

# %%
topthree[0]['TOTAL_RELEASES'].plot.bar(label='Top 3 total releases',color='red', legend=None,title='2002')

# %%
topthree[1]['TOTAL_RELEASES'].plot.bar(label='Top 3 total releases',color='green', legend=None,title='2003')
topthree[1]
# Out:
#       YEAR                                      FACILITY_NAME  \
# 2640  2003  DUKE ENERGY CAROLINAS LLC - MARSHALL STEAM STA...
# 68    2003  DUKE ENERGY PROGRESS LLC - ROXBORO STEAM ELECT...
# 1747  2003  DUKE ENERGY CAROLINAS LLC - BELEWS CREEK STEAM...
#
#                                                CHEMICAL CARCINOGEN  \
# 2640  HYDROCHLORIC ACID (1995 AND AFTER ACID AEROSOL...         NO
# 68    HYDROCHLORIC ACID (1995 AND AFTER ACID AEROSOL...         NO
# 1747  HYDROCHLORIC ACID (1995 AND AFTER ACID AEROSOL...         NO
#
#       TOTAL_RELEASES  ON-SITE_RELEASE_TOTAL
# 2640      12000000.0             12000000.0
# 68        11000000.0             11000000.0
# 1747       8400000.0              8400000.0

# %%
topthree[2]['TOTAL_RELEASES'].plot.bar(label='Top 3 total releases',color='blue', legend=None,title='2004')

# %%
topthree[3]['TOTAL_RELEASES'].plot.bar(label='Top 3 total releases',color='yellow', legend=None,title='2005')

# %%
topthree[4]['TOTAL_RELEASES'].plot.bar(label='Top 3 total releases',color='pink', legend=None,title='2006')

# %%
industrysector = [num3[['YEAR','FACILITY_NAME','CHEMICAL','CARCINOGEN','INDUSTRY_SECTOR']] for num3 in NC_data]

# %%
industrysector[0]
yescar02=industrysector[0][CARCINOGEN[0]['CARCINOGEN']== 'YES']
print "Industry's associated with Carcinogen(2002)"
yescar02.groupby('INDUSTRY_SECTOR').mean()
# Out:
# Industry's associated with Carcinogen(2002)
#                                    YEAR
# INDUSTRY_SECTOR
# Beverages                          2002
# Chemical Wholesalers               2002
# Chemicals                          2002
# Computers and Electronic Products  2002
# Electric Utilities                 2002
# Electrical Equipment               2002
# Fabricated Metals                  2002
# Food                               2002
# Furniture                          2002
# Hazardous Waste                    2002
# Machinery                          2002
# Miscellaneous Manufacturing        2002
# Nonmetallic Mineral Product        2002
# Other                              2002
# Paper                              2002
# Petroleum                          2002
# Petroleum Bulk Terminals           2002
# Plastics and Rubber                2002
# Primary Metals                     2002
# Printing                           2002
# Textile Product                    2002
# ...

# %%
industrysector[0]
yescar02=industrysector[0][CARCINOGEN[0]['CARCINOGEN']== 'YES']
print "Chemicals associated with Carcinogen (2002)"
yescar02.groupby('CHEMICAL').mean()
# Out:
# Chemicals associated with Carcinogen (2002)
#                                       YEAR
# CHEMICAL
# 1,2-DICHLOROETHANE                    2002
# 1,3-BUTADIENE                         2002
# 1,3-DICHLOROPROPYLENE                 2002
# 1,4-DICHLOROBENZENE                   2002
# 1,4-DIOXANE                           2002
# 2,4-D BUTOXYETHYL ESTER               2002
# 4,4'-METHYLENEDIANILINE               2002
# ACETALDEHYDE                          2002
# ACRYLAMIDE                            2002
# ACRYLONITRILE                         2002
# ALPHA-NAPHTHYLAMINE                   2002
# ARSENIC                               2002
# BENZENE                               2002
# BENZO(G,H,I)PERYLENE                  2002
# BERYLLIUM                             2002
# CADMIUM                               2002
# CARBON TETRACHLORIDE                  2002
# CHLOROFORM                            2002
# CHROMIUM                              2002
# ...

# %%
onsite_vs_total = [num4[['YEAR','FACILITY_NAME','CHEMICAL','TOTAL_RELEASES','ON-SITE_RELEASE_TOTAL']] for num4 in NC_data]

# %%
onst2001 = onsite_vs_total[0]
onst2002 = onsite_vs_total[1]
onst2003 = onsite_vs_total[2]
onst2004 = onsite_vs_total[3]
onst2005 = onsite_vs_total[4]

onsite_vs_total[0]['Percentage of releases on site']=onsite_vs_total[0]['ON-SITE_RELEASE_TOTAL']/onsite_vs_total[0]['TOTAL_RELEASES']
onsite_vs_total[1]['Percentage of releases on site']=onsite_vs_total[1]['ON-SITE_RELEASE_TOTAL']/onsite_vs_total[1]['TOTAL_RELEASES']
onsite_vs_total[2]['Percentage of releases on site']=onsite_vs_total[2]['ON-SITE_RELEASE_TOTAL']/onsite_vs_total[2]['TOTAL_RELEASES']
onsite_vs_total[3]['Percentage of releases on site']=onsite_vs_total[3]['ON-SITE_RELEASE_TOTAL']/onsite_vs_total[3]['TOTAL_RELEASES']
onsite_vs_total[4]['Percentage of releases on site']=onsite_vs_total[4]['ON-SITE_RELEASE_TOTAL']/onsite_vs_total[4]['TOTAL_RELEASES']
# Out:
# C:\Users\Melvin\Anaconda2\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\Melvin\Anaconda2\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\Melvin\Anaconda2\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
this = [onsite_vs_total[i].sort_values('Percentage of releases on site', ascending=False)[0:20] for i in range(len(onsite_vs_total))]
this[2]
# Out:
#       YEAR                                      FACILITY_NAME  \
# 0     2004                         SOUTH ATLANTIC GALVANIZING
# 1686  2004                       MILLERCOORS LLC-EDEN BREWERY
# 1717  2004                                          US MARINE
# 1713  2004                                       LANXESS CORP
# 1709  2004                         SONOCO PRODUCTS CARTON DIV
# 1700  2004  DUKE ENERGY PROGRESS LLC - H F LEE ENERGY COMPLEX
# 1698  2004  BLUE RIDGE PAPER PRODUCTS INC (DBA EVERGREEN P...
# 1697  2004  ENGINEERED POLYMER SOLUTIONS INC D/B/A VALSPAR...
# 1694  2004  PILGRIM'S PRIDE CORP MARSHVILLE PROCESSING FAC...
# 1691  2004                                          AVOCA INC
# 1690  2004                 INTERNATIONAL PAPER- NEW BERN MILL
# 1689  2004                           INVISTA SA RL-WILMINGTON
# 1685  2004                 INTERNATIONAL PAPER- NEW BERN MILL
# 1719  2004                  DOMTAR PAPER CO LLC-PLYMOUTH MILL
# ...

# %%
zeroonsite2002=onsite_vs_total[0][onsite_vs_total[0]['Percentage of releases on site']== 0]
zeroonsite2003=onsite_vs_total[1][onsite_vs_total[1]['Percentage of releases on site']== 0]
zeroonsite2004=onsite_vs_total[2][onsite_vs_total[2]['Percentage of releases on site']== 0]
zeroonsite2005=onsite_vs_total[3][onsite_vs_total[3]['Percentage of releases on site']== 0]
zeroonsite2006=onsite_vs_total[4][onsite_vs_total[4]['Percentage of releases on site']== 0]

count02=len(zeroonsite2002);count03=len(zeroonsite2003);count04=len(zeroonsite2004)
count05=len(zeroonsite2005);count06=len(zeroonsite2006)

zeroonsite2002all=onsite_vs_total[0][onsite_vs_total[0]['Percentage of releases on site']== 1.0]
zeroonsite2003all=onsite_vs_total[1][onsite_vs_total[1]['Percentage of releases on site']== 1.0]
zeroonsite2004all=onsite_vs_total[2][onsite_vs_total[2]['Percentage of releases on site']== 1.0]
zeroonsite2005all=onsite_vs_total[3][onsite_vs_total[3]['Percentage of releases on site']== 1.0]
zeroonsite2006all=onsite_vs_total[4][onsite_vs_total[4]['Percentage of releases on site']== 1.0]

count02all=len(zeroonsite2002all);count03all=len(zeroonsite2003all);count04all=len(zeroonsite2004all)
count05all=len(zeroonsite2005all);count06all=len(zeroonsite2006all)
zero_on_site_release=[count02,count03,count04,count05,count06]
one_site_release_all =[count02all,count03all,count04all,count05all,count06all]

df2 = pd.DataFrame(zero_on_site_release).plot.bar(color='red')
df2.set_xlabel("Years",fontsize=12)
df2.set_ylabel("Number of facilites",fontsize=12)
df2.set_title("Number Facilities with no onsite releases")
df2.set_xticklabels(["2002","2003","2004","2005","2006"])

df3 = pd.DataFrame(one_site_release_all).plot.bar(color='green')
df3.set_xlabel("Years",fontsize=12)
df3.set_ylabel("Number of facilites",fontsize=12)
df3.set_title("Number Facilities with 100% onsite releases")
df3.set_xticklabels(["2002","2003","2004","2005","2006"])


print "Facility's with   0% on site releases---2002:",count02,"2003:",count03,"2004:",count04,"2005:",count05,"2006:",count06
print "Facility's with 100% on site releases---2002:",count02all,"2003:",count03all,"2004:",count04all,"2005:",count05all,"2006:",count06all
# Out:
# Facility's with   0% on site releases---2002: 171 2003: 158 2004: 168 2005: 159 2006: 188
# Facility's with 100% on site releases---2002: 1511 2003: 1486 2004: 1375 2005: 1318 2006: 1615
