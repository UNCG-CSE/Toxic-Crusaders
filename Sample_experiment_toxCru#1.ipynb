# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data1 = pd.read_csv('Zip_Zhvi_AllHomes.csv')
data_tri1 = pd.read_csv('TRI_2015_NC.csv')
data_tri_2014 = pd.read_csv('TRI_2014_NC.csv')
data_tri_2013 = pd.read_csv('TRI_2013_NC.csv')
data_tri_2012 = pd.read_csv('TRI_2012_NC.csv')

# %%
data_mean_house_yr = pd.read_csv('Zip_Zhvi_AllHomes.csv')

# %%
data3 = data1[data1["State"]=='NC']
data_3=data3.dropna()

# %%
data_tri1
# Out:
#       YEAR  TRI_FACILITY_ID        FRS_ID  \
# 0     2015  27709JMCSNONEIN  1.100120e+11
# 1     2015  2803WBRLCM5CRRE  1.100460e+11
# 2     2015  28111TLDYN2020A  1.100000e+11
# 3     2015  28328CMPBL224FA  1.100000e+11
# 4     2015  28456FDRLPRIEGE  1.100100e+11
# 5     2015  28456FDRLPRIEGE  1.100100e+11
# 6     2015  28012DKNRG253PL  1.100000e+11
# 7     2015  28012DKNRG253PL  1.100000e+11
# 8     2015  27610JNMTS4020A  1.100000e+11
# 9     2015  27962WYRHSTROWB  1.100140e+11
# 10    2015  2814WKZNBL485CE  1.100000e+11
# 11    2015  28080THTMK1TIMK  1.100100e+11
# 12    2015  27025PNHLLLINDS  1.100000e+11
# 13    2015  27806TXSGLHIGHW  1.100010e+11
# 14    2015  28689SMRSLHWY90  1.100070e+11
# 15    2015  2740WCNTRL296SE  1.100550e+11
# 16    2015  28682DKNRG8320E  1.100000e+11
# 17    2015  28120FRGHT1800N  1.100000e+11
# 18    2015  28357MNTRFHWY71  1.100010e+11
# 19    2015  27374MRSNN325WE  1.100070e+11
# 20    2015  27835HNDRX1101I  1.100020e+11
# ...

# %%
data_mean_house_yr=data_mean_house_yr.rename(columns={'RegionName':'ZIP'})
data_mean_house_yr
# Out:
#        RegionID    ZIP               City State  \
# 0         61639  10025           New York    NY
# 1         84654  60657            Chicago    IL
# 2         84616  60614            Chicago    IL
# 3         93144  79936            El Paso    TX
# 4         84640  60640            Chicago    IL
# 5         91733  77084            Houston    TX
# 6         97564  94109      San Francisco    CA
# 7         90668  75070           McKinney    TX
# 8         62037  11226           New York    NY
# 9         91940  77449            Cypress    TX
# 10        61630  10016           New York    NY
# 11        71831  32162       The Villages    FL
# 12        62045  11235           New York    NY
# 13        84646  60647            Chicago    IL
# 14        74242  37211          Nashville    TN
# 15        96107  90250          Hawthorne    CA
# 16        74101  37013          Nashville    TN
# 17        84620  60618            Chicago    IL
# ...

# %%
data_tri1['onsite_mean']=data_tri1.groupby('ZIP')['ON-SITE_RELEASE_TOTAL'].transform('mean')

# %%
data_tri_2012['onsite_mean']=data_tri_2012.groupby('ZIP')['ON-SITE_RELEASE_TOTAL'].transform('mean')

# %%
data_tri_2013['onsite_mean']=data_tri_2013.groupby('ZIP')['ON-SITE_RELEASE_TOTAL'].transform('mean')

# %%
data_tri_2014['onsite_mean']=data_tri_2014.groupby('ZIP')['ON-SITE_RELEASE_TOTAL'].transform('mean')

# %%
data_tri1
# Out:
#       YEAR  TRI_FACILITY_ID        FRS_ID  \
# 0     2015  27709JMCSNONEIN  1.100120e+11
# 1     2015  2803WBRLCM5CRRE  1.100460e+11
# 2     2015  28111TLDYN2020A  1.100000e+11
# 3     2015  28328CMPBL224FA  1.100000e+11
# 4     2015  28456FDRLPRIEGE  1.100100e+11
# 5     2015  28456FDRLPRIEGE  1.100100e+11
# 6     2015  28012DKNRG253PL  1.100000e+11
# 7     2015  28012DKNRG253PL  1.100000e+11
# 8     2015  27610JNMTS4020A  1.100000e+11
# 9     2015  27962WYRHSTROWB  1.100140e+11
# 10    2015  2814WKZNBL485CE  1.100000e+11
# 11    2015  28080THTMK1TIMK  1.100100e+11
# 12    2015  27025PNHLLLINDS  1.100000e+11
# 13    2015  27806TXSGLHIGHW  1.100010e+11
# 14    2015  28689SMRSLHWY90  1.100070e+11
# 15    2015  2740WCNTRL296SE  1.100550e+11
# 16    2015  28682DKNRG8320E  1.100000e+11
# 17    2015  28120FRGHT1800N  1.100000e+11
# 18    2015  28357MNTRFHWY71  1.100010e+11
# 19    2015  27374MRSNN325WE  1.100070e+11
# 20    2015  27835HNDRX1101I  1.100020e+11
# ...

# %%
data_tri_2012
# Out:
#       YEAR  TRI_FACILITY_ID        FRS_ID  \
# 0     2012  28401MRDHS1312S  110000350183
# 1     2012  28613RCRPNBOX87  110000350799
# 2     2012  27025PNHLLLINDS  110000345118
# 3     2012  27320BHMFLROUTE  110009856165
# 4     2012  28025MRCHM723CO  110000348035
# 5     2012  27406VNKST241DY  110067042122
# 6     2012  28451MRCND1690N  110000350316
# 7     2012  2814WKZNBL485CE  110000348936
# 8     2012  27264SPRBR1350W  110000554533
# 9     2012  28115CNCRT123HA  110006529845
# 10    2012  27330WBRSN2101N  110000346377
# 11    2012  28213NCLCH14700  110059780198
# 12    2012  2839WSWSPR545WE  110055129276
# 13    2012  28560MLMLK605AV  110000350469
# 14    2012  28562STNDY101IN  110000800205
# 15    2012  27306HMNTS149HO  110022561379
# 16    2012  28412PXLCX3314R  110001480317
# 17    2012  27052DKNRGPINEH  110000604141
# 18    2012  27420GLBRC7300F  110000847601
# 19    2012  28144NTNLSCEDAR  110056525835
# 20    2012  28024DKNRGDUKEP  110006424404
# ...

# %%
data_tri_2013
# Out:
#       YEAR  TRI_FACILITY_ID        FRS_ID  \
# 0     2013  27292PDMNTRTE14  110000346073
# 1     2013  28804RVCSC275AI  110009296699
# 2     2013  28792SLCRP700SH  110000351707
# 3     2013  28560WYRHSSTREE  110000350478
# 4     2013  28111TLDYN2020A  110000348589
# 5     2013  28111TLDYN2020A  110000348589
# 6     2013  28208SHLND3930G  110000349329
# 7     2013  28451CTNGSRTE74  110004045701
# 8     2013  28213FLRDSHWY11  110012474697
# 9     2013  28024DKNRGDUKEP  110006424404
# 10    2013  28210FRTLY2911N  110000349383
# 11    2013  28392CRLNFHWY87  110007377338
# 12    2013  2853WSWHBR3248F  110027981922
# 13    2013  28120HCHSTPOBOX  110000348687
# 14    2013  28716CHMPNMAINS  110009846480
# 15    2013  27229PRDNCSTATE  110007376865
# 16    2013  28120HCHSTPOBOX  110000348687
# 17    2013  28739GNRLL3010S  110000351565
# 18    2013  28739GNRLL3010S  110000351565
# 19    2013  27573MYLCT10660  110057382666
# 20    2013  27573MYLCT10660  110057382666
# ...

# %%
data_tri_2014
# Out:
#       YEAR  TRI_FACILITY_ID        FRS_ID  \
# 0     2014  28682DKNRG8320E  110000351397
# 1     2014  28682DKNRG8320E  110000351397
# 2     2014  28206CNCRT3823R  110001479775
# 3     2014  28682DKNRG8320E  110000351397
# 4     2014  27565NVRSL311PR  110012656429
# 5     2014  28392CRLNFHWY87  110007377338
# 6     2014  28560WYRHSSTREE  110000350478
# 7     2014  27834MTLLX251IN  110015308111
# 8     2014  28054WLSHC207TE  110041964201
# 9     2014  28804RVCSC275AI  110009296699
# 10    2014  28345PRGRSNCSR1  110004060417
# 11    2014  27377NGNRD1239R  110000346466
# 12    2014  27893WLTRK2500A  110004018063
# 13    2014  2808WCNCRT11HLI  110044314391
# 14    2014  28054JCHRL1010E  110064177536
# 15    2014  28349GLFRDROUTE  110000349953
# 16    2014  28166NGNRD250OL  110000349169
# 17    2014  27302CLLNC100MA  110006860708
# 18    2014  28560WYRHSSTREE  110000350478
# 19    2014  28086TNCRPHWY29  110007660281
# 20    2014  28472CMPBL1476S  110000350398
# ...

# %%
data_combine = [data_tri1,data_tri_2014,data_tri_2013,data_tri_2012]

# %%
data_tri_all_yr=pd.concat(data_combine,join='outer')

# %%
    data_tri_all_yr['PARENT_COMPANY_NAME'][data_tri_all_yr['onsite_mean']==data_tri_all_yr['onsite_mean'].max()]
# Out:
# 85      UNITED GLOBAL FOODS US HOLDINGS INC
# 111     UNITED GLOBAL FOODS US HOLDINGS INC
# 884     UNITED GLOBAL FOODS US HOLDINGS INC
# 1331    UNITED GLOBAL FOODS US HOLDINGS INC
# 1556    UNITED GLOBAL FOODS US HOLDINGS INC
# Name: PARENT_COMPANY_NAME, dtype: object

# %%
data_merge = pd.merge(data_tri_all_yr,data_mean_house_yr,on='ZIP', how='inner')

# %%
data_tri_2012[(data_tri_2012['onsite_mean']== data_tri_2012['onsite_mean'].max())]
# Out:
#       YEAR  TRI_FACILITY_ID        FRS_ID        FACILITY_NAME  \
# 448   2012  28392CRLNFHWY87  110007377338  SMITHFIELD-TAR HEEL
# 751   2012  28392CRLNFHWY87  110007377338  SMITHFIELD-TAR HEEL
# 752   2012  28392CRLNFHWY87  110007377338  SMITHFIELD-TAR HEEL
# 1744  2012  28392CRLNFHWY87  110007377338  SMITHFIELD-TAR HEEL
# 2204  2012  28392CRLNFHWY87  110007377338  SMITHFIELD-TAR HEEL
#
#          STREET_ADDRESS      CITY  COUNTY  ST    ZIP  BIA_CODE     ...       \
# 448   15855 HWY 87 WEST  TAR HEEL  BLADEN  NC  28392       NaN     ...
# 751   15855 HWY 87 WEST  TAR HEEL  BLADEN  NC  28392       NaN     ...
# 752   15855 HWY 87 WEST  TAR HEEL  BLADEN  NC  28392       NaN     ...
# 1744  15855 HWY 87 WEST  TAR HEEL  BLADEN  NC  28392       NaN     ...
# 2204  15855 HWY 87 WEST  TAR HEEL  BLADEN  NC  28392       NaN     ...
#
#      8.6_TREATMENT_ON-SITE  8.7_TREATMENT_OFF-SITE  \
# 448             2673437.00                     0.0
# ...

# %%
data_tri_2012[(data_tri_2012['onsite_mean']== data_tri_2012['onsite_mean'].min())]
# Out:
#       YEAR  TRI_FACILITY_ID        FRS_ID  \
# 14    2012  28562STNDY101IN  110000800205
# 25    2012  2721WCHMTK697CU  110035820403
# 71    2012  28387NGRSL1725U  110001492992
# 73    2012  28387NGRSL1725U  110001492992
# 141   2012  28071RCSQR2075H  110008055692
# 155   2012  28174WMPLR205ED  110000349178
# 165   2012  28675PNRCLECLIP  110000587044
# 177   2012  27526JHNDR6501H  110006722092
# 202   2012  28360LKYST88CAT  110001493090
# 289   2012  27712WNRTH4112L  110006625651
# 321   2012  27526JHNDR6501H  110006722092
# 334   2012  27822NXNSB6SPAR  110020516431
# 339   2012  28071RCSQR2075H  110008055692
# 368   2012  27591SMNSNSR230  110057653427
# 373   2012  27377NGNRD1239R  110000346466
# 377   2012  28337CMPBL1106W  110000349891
# 380   2012  28645BRNHRPLAN3  110000350959
# 381   2012  28678CRLNW165HA  110022904794
# 397   2012  27804SCRCR2151N  110000347517
# 398   2012  27374MRSNN325WE  110006722029
# 423   2012  27377NGNRD1239R  110000346466
# ...

# %%
data_tri_2013[(data_tri_2013['onsite_mean']== data_tri_2013['onsite_mean'].max())]
# Out:
#       YEAR  TRI_FACILITY_ID        FRS_ID        FACILITY_NAME  \
# 11    2013  28392CRLNFHWY87  110007377338  SMITHFIELD-TAR HEEL
# 289   2013  28392CRLNFHWY87  110007377338  SMITHFIELD-TAR HEEL
# 1051  2013  28392CRLNFHWY87  110007377338  SMITHFIELD-TAR HEEL
# 2073  2013  28392CRLNFHWY87  110007377338  SMITHFIELD-TAR HEEL
# 2202  2013  28392CRLNFHWY87  110007377338  SMITHFIELD-TAR HEEL
#
#          STREET_ADDRESS      CITY  COUNTY  ST    ZIP  BIA_CODE     ...       \
# 11    15855 HWY 87 WEST  TAR HEEL  BLADEN  NC  28392       NaN     ...
# 289   15855 HWY 87 WEST  TAR HEEL  BLADEN  NC  28392       NaN     ...
# 1051  15855 HWY 87 WEST  TAR HEEL  BLADEN  NC  28392       NaN     ...
# 2073  15855 HWY 87 WEST  TAR HEEL  BLADEN  NC  28392       NaN     ...
# 2202  15855 HWY 87 WEST  TAR HEEL  BLADEN  NC  28392       NaN     ...
#
#      8.6_TREATMENT_ON-SITE  8.7_TREATMENT_OFF-SITE  \
# 11                224489.0                     0.0
# ...

# %%
data_tri_2013[(data_tri_2013['onsite_mean']== data_tri_2013['onsite_mean'].min())]
# Out:
#       YEAR  TRI_FACILITY_ID        FRS_ID  \
# 69    2013  27374MRSNN325WE  110006722029
# 76    2013  28678CRLNW165HA  110022904794
# 90    2013  28163TXTRN614NC  110001488426
# 129   2013  28675PNRCLECLIP  110000587044
# 147   2013  28174WMPLR205ED  110000349178
# 157   2013  27822NXNSB6SPAR  110020516431
# 181   2013  27712CRMTC5000I  110001500572
# 182   2013  27242PRDNCHWY21  110009716281
# 184   2013  27278WLMRL67US7  110030816534
# 195   2013  28071RCSQR2075H  110008055692
# 196   2013  27501KDDFR141JU  110001492821
# 201   2013  27242PRDNCHWY21  110009716281
# 219   2013  28906SXTLS250SN  110015324282
# 233   2013  27377NGNRD1239R  110000346466
# 303   2013  28758BRNFRPOBOX  110018548124
# 306   2013  28360LKYST88CAT  110001493090
# 309   2013  27229MNTRF203MO  110006804985
# 325   2013  28562STNDY101IN  110000800205
# 332   2013  28360LKYST88CAT  110001493090
# 404   2013  28523CVCTYHWY10  110007657678
# 407   2013  28202DMMLL620W1  110000349187
# ...

# %%
data_tri_2014[(data_tri_2014['onsite_mean']== data_tri_2014['onsite_mean'].max())]
# Out:
#       YEAR  TRI_FACILITY_ID        FRS_ID        FACILITY_NAME  \
# 5     2014  28392CRLNFHWY87  110007377338  SMITHFIELD-TAR HEEL
# 858   2014  28392CRLNFHWY87  110007377338  SMITHFIELD-TAR HEEL
# 956   2014  28392CRLNFHWY87  110007377338  SMITHFIELD-TAR HEEL
# 1202  2014  28392CRLNFHWY87  110007377338  SMITHFIELD-TAR HEEL
# 1321  2014  28392CRLNFHWY87  110007377338  SMITHFIELD-TAR HEEL
#
#          STREET_ADDRESS      CITY  COUNTY  ST    ZIP  BIA_CODE     ...       \
# 5     15855 HWY 87 WEST  TAR HEEL  BLADEN  NC  28392       NaN     ...
# 858   15855 HWY 87 WEST  TAR HEEL  BLADEN  NC  28392       NaN     ...
# 956   15855 HWY 87 WEST  TAR HEEL  BLADEN  NC  28392       NaN     ...
# 1202  15855 HWY 87 WEST  TAR HEEL  BLADEN  NC  28392       NaN     ...
# 1321  15855 HWY 87 WEST  TAR HEEL  BLADEN  NC  28392       NaN     ...
#
#      8.6_TREATMENT_ON-SITE  8.7_TREATMENT_OFF-SITE  \
# 5                1151466.8                     0.0
# ...

# %%
data_tri_2014[(data_tri_2014['onsite_mean']== data_tri_2014['onsite_mean'].min())]
# Out:
#       YEAR  TRI_FACILITY_ID        FRS_ID  \
# 20    2014  28472CMPBL1476S  110000350398
# 23    2014  28758BRNFRPOBOX  110018548124
# 24    2014  28758BRNFRPOBOX  110018548124
# 38    2014  2839WTRKYM564TU  110043582138
# 56    2014  27374MRSNN325WE  110006722029
# 100   2014  28472CMPBL1476S  110000350398
# 119   2014  28904CLMNC788TU  110009857903
# 124   2014  27374MRSNN325WE  110006722029
# 126   2014  27374MRSNN325WE  110006722029
# 143   2014  28202DMMLL620W1  110000349187
# 145   2014  28472CMPBL1476S  110000350398
# 150   2014  28472CMPBL1476S  110000350398
# 187   2014  28523CVCTYHWY10  110007657678
# 195   2014  2839WTRKYM564TU  110043582138
# 214   2014  28609CMMSCPOBOX  110009855237
# 223   2014  28472CMPBL1476S  110000350398
# 264   2014  27204CLVLN201YZ  110000345546
# 275   2014  27229MNTRF203MO  110006804985
# 279   2014  2857WFRNKD413HW  110043670382
# 344   2014  28697HLLYFRIVER  110002100100
# 411   2014  28360LKYST88CAT  110001493090
# ...

# %%
data_tri1[(data_tri1['onsite_mean']== data_tri1['onsite_mean'].max())]
# Out:
#       YEAR  TRI_FACILITY_ID        FRS_ID        FACILITY_NAME  \
# 85    2015  28392CRLNFHWY87  1.100070e+11  SMITHFIELD-TAR HEEL
# 111   2015  28392CRLNFHWY87  1.100070e+11  SMITHFIELD-TAR HEEL
# 884   2015  28392CRLNFHWY87  1.100070e+11  SMITHFIELD-TAR HEEL
# 1331  2015  28392CRLNFHWY87  1.100070e+11  SMITHFIELD-TAR HEEL
# 1556  2015  28392CRLNFHWY87  1.100070e+11  SMITHFIELD-TAR HEEL
#
#          STREET_ADDRESS      CITY  COUNTY  ST    ZIP  BIA_CODE     ...       \
# 85    15855 HWY 87 WEST  TAR HEEL  BLADEN  NC  28392       NaN     ...
# 111   15855 HWY 87 WEST  TAR HEEL  BLADEN  NC  28392       NaN     ...
# 884   15855 HWY 87 WEST  TAR HEEL  BLADEN  NC  28392       NaN     ...
# 1331  15855 HWY 87 WEST  TAR HEEL  BLADEN  NC  28392       NaN     ...
# 1556  15855 HWY 87 WEST  TAR HEEL  BLADEN  NC  28392       NaN     ...
#
#       8.5_RECYCLING_OFF-SITE  8.6_TREATMENT_ON-SITE  8.7_TREATMENT_OFF-SITE  \
# ...

# %%
data_tri1[(data_tri1['onsite_mean']== data_tri1['onsite_mean'].min())]
# Out:
#       YEAR  TRI_FACILITY_ID        FRS_ID  \
# 19    2015  27374MRSNN325WE  1.100070e+11
# 56    2015  27229MNTRF203MO  1.100070e+11
# 160   2015  27374MRSNN325WE  1.100070e+11
# 183   2015  28360LKYST88CAT  1.100010e+11
# 197   2015  28360LKYST88CAT  1.100010e+11
# 207   2015  28351PRLLRSTATE  1.100140e+11
# 289   2015  28472CMPBL1476S  1.100000e+11
# 322   2015  28472CMPBL1476S  1.100000e+11
# 362   2015  28071RCSQR2075H  1.100080e+11
# 376   2015  28675PNRCLECLIP  1.100010e+11
# 379   2015  27909STHTL1245F  1.100100e+11
# 447   2015  27379NRGYD753CO  1.100200e+11
# 478   2015  27864WSTNGHWY43  1.100560e+11
# 518   2015  28906CLFTNHWY14  1.100450e+11
# 524   2015  28678CRLNW165HA  1.100230e+11
# 528   2015  27242PRDNCHWY21  1.100100e+11
# 531   2015  28546MNSFT352WH  1.100010e+11
# 548   2015  27874CRLNWEAST1  1.100010e+11
# 574   2015  27299CRTRM4264L  1.100230e+11
# 621   2015  28163TXTRN614NC  1.100010e+11
# 623   2015  28163TXTRN614NC  1.100010e+11
# ...

# %%
data_tri_all_yr[(data_tri_all_yr['onsite_mean']== data_tri_all_yr['onsite_mean'].max())]
# Out:
#        8.5_RECYCLING_OFF-SITE  5.1_FUGITIVE_AIR  5.2_STACK_AIR    5.3_WATER  \
# 85                        0.0               5.0          941.2        5.000
# 111                       0.0               5.0            5.0        0.000
# 884                       0.0               0.0            0.0  3903540.000
# 1331                      0.0          133588.0         5710.0      540.312
# 1556                      0.0            2270.0        79297.0       89.000
#
#       5.4.1_UNDERGROUND_CLASS_I  5.4.2_UNDERGROUND_CLASS_II-V  \
# 85                            0                             0
# 111                           0                             0
# 884                           0                             0
# 1331                          0                             0
# 1556                          0                             0
#
#       5.4_UNDERGROUND  5.5.1A_RCRA_C_LANDFILLS  5.5.1B_OTHER_LANDFILLS  \
# ...

# %%
data_tri_all_yr[(data_tri_all_yr['onsite_mean']== data_tri_all_yr['onsite_mean'].min())]
# Out:
#        8.5_RECYCLING_OFF-SITE  5.1_FUGITIVE_AIR  5.2_STACK_AIR  5.3_WATER  \
# 19                   15290.07               0.0            0.0        0.0
# 56                       0.00               0.0            0.0        0.0
# 160                  37152.00               0.0            0.0        0.0
# 183                 316956.00               0.0            0.0        0.0
# 197                  10850.00               0.0            0.0        0.0
# 207                      0.00               0.0            0.0        0.0
# 289                      0.00               0.0            0.0        0.0
# 322                      0.00               0.0            0.0        0.0
# 362                      0.00               0.0            0.0        0.0
# 376                      0.00               0.0            0.0        0.0
# 379                      0.00               0.0            0.0        0.0
# 447                      0.00               0.0            0.0        0.0
# ...

# %%
data_merge['onsite_mean'].max()
# Out:
# 169615.81754300001

# %%
data_merge[(data_merge['onsite_mean']== data_merge['onsite_mean'].max())]
# Out:
#        8.5_RECYCLING_OFF-SITE  5.1_FUGITIVE_AIR  5.2_STACK_AIR  5.3_WATER  \
# 3666                      0.0            0.0000         1.8000   68.00000
# 3667                      0.0           19.5400      5115.0000   22.00000
# 3668                      0.0            0.0000        17.0000    4.00000
# 3669                      0.0            0.0016         0.0000    0.00000
# 3670                      0.0            0.0000      2246.2000   22.00000
# 3671                      0.0            0.0151         0.0095    0.00000
# 3672                      0.0            0.0000        23.0000    0.00743
# 3673                      0.0            0.0000       461.3000    0.00000
# 3674                      0.0            0.0000         0.0000    0.00000
# 3675                      0.0            0.0000         5.0000    0.00000
#
#       5.4.1_UNDERGROUND_CLASS_I  5.4.2_UNDERGROUND_CLASS_II-V  \
# 3666                          0                             0
# ...

# %%
data_3
# Out:
#        RegionID  RegionName            City State          Metro   CountyName  \
# 19        69816       28269       Charlotte    NC      Charlotte  Mecklenburg
# 56        69823       28277       Charlotte    NC      Charlotte  Mecklenburg
# 126       69672       28027         Concord    NC      Charlotte     Cabarrus
# 157       69849       28314    Fayetteville    NC   Fayetteville   Cumberland
# 170       69450       27610         Raleigh    NC        Raleigh         Wake
# 250       69431       27587     Wake Forest    NC        Raleigh         Wake
# 304       69699       28078    Huntersville    NC      Charlotte  Mecklenburg
# 325       69491       27707          Durham    NC         Durham       Durham
# 345       70056       28601         Hickory    NC        Hickory      Catawba
# 358       69275       27284    Kernersville    NC  Winston-Salem      Forsyth
# 401       69489       27705          Durham    NC         Durham       Durham
# ...

# %%
 a = int('1')+1
a
b=str(a)+'-01'
b
# Out:
# '2-01'

# %%
def get_houseprice_mean_by_year(farg, *argv):
    for arg in argv:
        next_year = int(year)+1
        data_mean_house_yr[year+"-mean"] = data_mean_house_yr[year+"-01":str (next_year)+"-01"].transform('mean',axis=1)
        return data_mean_house_yr

# %%
data_mean_house_yr.apply(get_houseprice_mean_by_year("2012"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-0c83b5c2971e> in <module>()
# ----> 1 data_mean_house_yr.apply(get_houseprice_mean_by_year("2012"))
#
# /anaconda/lib/python3.6/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4260                         f, axis,
#    4261                         reduce=reduce,
# -> 4262                         ignore_failures=ignore_failures)
#    4263             else:
#    4264                 return self._apply_broadcast(f, axis)
#
# /anaconda/lib/python3.6/site-packages/pandas/core/frame.py in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4356             try:
#    4357                 for i, v in enumerate(series_gen):
# -> 4358                     results[i] = func(v)
#    4359                     keys.append(v.name)
# ...

# %%
data_mean_house_yr['2012'] = data_mean_house_yr.loc[:,'2012-01':'2012-12'].mean(axis=1)

# %%
data_mean_house_yr
# Out:
#        RegionID    ZIP               City State  \
# 0         61639  10025           New York    NY
# 1         84654  60657            Chicago    IL
# 2         84616  60614            Chicago    IL
# 3         93144  79936            El Paso    TX
# 4         84640  60640            Chicago    IL
# 5         91733  77084            Houston    TX
# 6         97564  94109      San Francisco    CA
# 7         90668  75070           McKinney    TX
# 8         62037  11226           New York    NY
# 9         91940  77449            Cypress    TX
# 10        61630  10016           New York    NY
# 11        71831  32162       The Villages    FL
# 12        62045  11235           New York    NY
# 13        84646  60647            Chicago    IL
# 14        74242  37211          Nashville    TN
# 15        96107  90250          Hawthorne    CA
# 16        74101  37013          Nashville    TN
# 17        84620  60618            Chicago    IL
# ...

# %%
data_mean_house_yr['2013'] = data_mean_house_yr.loc[:,'2013-01':'2013-12'].mean(axis=1)

# %%
data_mean_house_yr['2014'] = data_mean_house_yr.loc[:,'2014-01':'2014-12'].mean(axis=1)

# %%
data_mean_house_yr['2015'] = data_mean_house_yr.loc[:,'2015-01':'2015-12'].mean(axis=1)

# %%
data_mean_house_yr
# Out:
#        RegionID    ZIP               City State  \
# 0         61639  10025           New York    NY
# 1         84654  60657            Chicago    IL
# 2         84616  60614            Chicago    IL
# 3         93144  79936            El Paso    TX
# 4         84640  60640            Chicago    IL
# 5         91733  77084            Houston    TX
# 6         97564  94109      San Francisco    CA
# 7         90668  75070           McKinney    TX
# 8         62037  11226           New York    NY
# 9         91940  77449            Cypress    TX
# 10        61630  10016           New York    NY
# 11        71831  32162       The Villages    FL
# 12        62045  11235           New York    NY
# 13        84646  60647            Chicago    IL
# 14        74242  37211          Nashville    TN
# 15        96107  90250          Hawthorne    CA
# 16        74101  37013          Nashville    TN
# 17        84620  60618            Chicago    IL
# ...

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,3,5])
data_mean_house_yr.iloc[150:200].plot(y=['2012','2013','2014','2015'],ax=ax)
#plt.plot(x=data_mean_house_yr.iloc[150:200],y=['2012','2013','2014','2015'])

plt.show()

# %%
data_toplot_new= pd.merge(data_mean_house_yr,data_tri_all_yr,on='ZIP',how='inner')

# %%
data_tri_all_yr.groupby('ZIP')

# %%
data_toplot_new
# Out:
#       RegionID    ZIP       City State      Metro   CountyName  SizeRank  \
# 0        69816  28269  Charlotte    NC  Charlotte  Mecklenburg        20
# 1        69816  28269  Charlotte    NC  Charlotte  Mecklenburg        20
# 2        69816  28269  Charlotte    NC  Charlotte  Mecklenburg        20
# 3        69816  28269  Charlotte    NC  Charlotte  Mecklenburg        20
# 4        69816  28269  Charlotte    NC  Charlotte  Mecklenburg        20
# 5        69816  28269  Charlotte    NC  Charlotte  Mecklenburg        20
# 6        69816  28269  Charlotte    NC  Charlotte  Mecklenburg        20
# 7        69816  28269  Charlotte    NC  Charlotte  Mecklenburg        20
# 8        69816  28269  Charlotte    NC  Charlotte  Mecklenburg        20
# 9        69816  28269  Charlotte    NC  Charlotte  Mecklenburg        20
# 10       69816  28269  Charlotte    NC  Charlotte  Mecklenburg        20
# 11       69816  28269  Charlotte    NC  Charlotte  Mecklenburg        20
# ...

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,3,5])
data_toplot.iloc[0:20].plot(y=['2012','2013','2014','2015'],ax=ax)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-fa4ad052f640> in <module>()
#       2
#       3 ax = fig.add_axes([0,0,3,5])
# ----> 4 data_toplot.iloc[0:20].plot(y=['2012','2013','2014','2015'],ax=ax)
#       5 plt.show()
#
# NameError: name 'data_toplot' is not defined
