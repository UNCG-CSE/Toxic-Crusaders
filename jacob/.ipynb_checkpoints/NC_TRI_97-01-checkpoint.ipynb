# %%
# %pylab inline
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy, csv
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## North Carolina TRI Data, 1997-2001
#
# In this notebook, we'll be looking at TRI reported releases in North Carolina for the years 1997 through 2001. The three main goals of this notebook are:
#
#     - Explore top releasing facilities in terms of total releases and carcinogenic releases
#     - Explore top releasing industry sectors in terms of total releases and carcinogenic releases
#     - Visualize on-site releases in NC over this time period using Basemap
#
# #### Top Releasing Facilities
# Identifying the facilities in NC that have the highest total, and carcinogenic, releases during this time period will give us an idea of the locations in the state which may be most heavily affected by toxic release.
#
# #### Top Releasing Industry Sectors
# Looking at the top releasing industry sectors for NC will be interesting in and of itself, and will let us see if releases in particular sectors are high because of the sector itself or because of the relative density of the industry type in the state of NC. This will be relevant to compare to other states later on.
#
# #### Basemap Visualization
# Using Basemap to visualise features of these data in NC will be a good way to think about which features are amenable and relevant to geographical mapping, as opposed to numerical trends that are more naturally represented with charts.

# %% [markdown]
# ### Importing the TRI Data

# %%
# reading in each set of csv data
nc_97 = pd.read_csv('./data/TRI_1997_NC.csv')
nc_98 = pd.read_csv('./data/TRI_1998_NC.csv')
nc_99 = pd.read_csv('./data/TRI_1999_NC.csv')
nc_00 = pd.read_csv('./data/TRI_2000_NC.csv')
nc_01 = pd.read_csv('./data/TRI_2001_NC.csv')

# storing the data in a common array to aggregate for comprehensions, etc
nc_data = [nc_97,nc_98,nc_99,nc_00,nc_01]

# %% [markdown]
# # Top Releasing Facilities

# %% [markdown]
# ## Top Releasing Facilities - Total

# %%
#separating out attributes of interest
totalreleases = [yr[['YEAR','FACILITY_NAME','CHEMICAL','TOTAL_RELEASES','LATITUDE','LONGITUDE']] for yr in nc_data]
topten_byyear = [totalreleases[i].sort_values('TOTAL_RELEASES', ascending=False)[0:10] for i in range(len(totalreleases))]

# %%
#helper function for mapping array of points onto NC map
def mapNClocations(latvals, lngvals, maptype='TRI Facilities'):
    plt.figure(figsize = (20,20))

    nc = Basemap(projection='merc', resolution='h',
                         llcrnrlon = -84.5, urcrnrlon = -75.2,
                         llcrnrlat = 34.0, urcrnrlat = 36.9)

    nc.drawcountries()
    nc.drawstates()
    nc.drawcoastlines()
    nc.drawrivers(linewidth = 1, color='#2471a3')
    nc.fillcontinents(color = 'coral')
    nc.drawmapboundary()


    x, y = nc(lngvals, latvals)
    plt.title("%s" % maptype)
    nc.scatter(x, y, s=100, c='#214fc1', zorder=10)

# %% [markdown]
# ### Total Toxic Releases 1997 - Top Ten

# %%
topten_byyear[0]['TOTAL_RELEASES'].plot.bar(label='total releases',color='#B8336A', legend=None)
mapNClocations(topten_byyear[0].LATITUDE.values,topten_byyear[0].LONGITUDE.values,'Top Releasing TRI Facilities - 1997')
topten_byyear[0]
# Out:
#       YEAR                                      FACILITY_NAME  \
# 2512  1997                             ELEMENTIS CHROMIUM INC
# 1197  1997                               PCS PHOSPHATE CO INC
# 1538  1997                               PCS PHOSPHATE CO INC
# 807   1997                                SMITHFIELD-TAR HEEL
# 608   1997                GERDAU LONG STEEL NA-CHARLOTTE MILL
# 942   1997  BLUE RIDGE PAPER PRODUCTS INC (DBA EVERGREEN P...
# 281   1997     SHURTAPE TECHNOLOGIES LLC - HICKORY TAPE PLANT
# 1065  1997                INTERNATIONAL PAPER RIEGELWOOD MILL
# 2266  1997                  DOMTAR PAPER CO LLC-PLYMOUTH MILL
# 107   1997                    RAILROAD FRICTION PRODUCTS CORP
#
#                                                CHEMICAL  TOTAL_RELEASES  \
# 2512  CHROMIUM COMPOUNDS(EXCEPT CHROMITE ORE MINED I...       9120298.0
# 1197                                    PHOSPHORIC ACID       8391999.0
# 1538                                            AMMONIA       3692213.0
# 807                                   NITRATE COMPOUNDS       3682714.0
# 608                                      ZINC COMPOUNDS       3292326.0
# 942                                            METHANOL       1932700.0
# 281                                             TOLUENE       1864554.0
# 1065                                           METHANOL       1571000.0
# 2266                                           METHANOL       1480000.0
# 107                                            N-HEXANE       1120000.0
#
#        LATITUDE  LONGITUDE
# 2512  34.372516 -77.859466
# 1197  35.377450 -76.778816
# 1538  35.377450 -76.778816
# 807   34.746500 -78.806100
# 608   35.339020 -80.829260
# 942   35.535600 -82.841900
# 281   35.738000 -81.309000
# 1065  34.352200 -78.212500
# 2266  35.861716 -76.779683
# 107   34.762788 -79.370238

# %% [markdown]
# ### Total Toxic Releases 1998 - Top Ten

# %%
topten_byyear[1]['TOTAL_RELEASES'].plot.bar(label='total releases',color='#726DA8', legend=None)
mapNClocations(topten_byyear[1].LATITUDE.values,topten_byyear[1].LONGITUDE.values,'Top Releasing TRI Facilities - 1998')

topten_byyear[1]
# Out:
#       YEAR                                      FACILITY_NAME  \
# 2930  1998  DUKE ENERGY CAROLINAS LLC - BELEWS CREEK STEAM...
# 2660  1998  DUKE ENERGY PROGRESS LLC - ROXBORO STEAM ELECT...
# 682   1998  DUKE ENERGY CAROLINAS LLC - MARSHALL STEAM STA...
# 2311  1998                             ELEMENTIS CHROMIUM INC
# 1610  1998                               PCS PHOSPHATE CO INC
# 2912  1998  DUKE ENERGY PROGRESS LLC-MAYO ELECTRIC GENERAT...
# 2664  1998                                SMITHFIELD-TAR HEEL
# 1310  1998    DUKE ENERGY CAROLINAS LLC - ALLEN STEAM STATION
# 1702  1998  DUKE ENERGY CAROLINAS LLC - ROGERS ENERGY COMPLEX
# 1167  1998  DUKE ENERGY PROGRESS LLC - L V SUTTON ENERGY C...
#
#                                                CHEMICAL  TOTAL_RELEASES  \
# 2930  HYDROCHLORIC ACID (1995 AND AFTER ACID AEROSOL...      14000005.0
# 2660  HYDROCHLORIC ACID (1995 AND AFTER ACID AEROSOL...      14000000.0
# 682   HYDROCHLORIC ACID (1995 AND AFTER ACID AEROSOL...      12000005.0
# 2311  CHROMIUM COMPOUNDS(EXCEPT CHROMITE ORE MINED I...      10019412.0
# 1610                                    PHOSPHORIC ACID       7678354.0
# 2912  HYDROCHLORIC ACID (1995 AND AFTER ACID AEROSOL...       4400000.0
# 2664                                  NITRATE COMPOUNDS       4116033.0
# 1310  HYDROCHLORIC ACID (1995 AND AFTER ACID AEROSOL...       3800005.0
# 1702  HYDROCHLORIC ACID (1995 AND AFTER ACID AEROSOL...       3400005.0
# 1167  HYDROCHLORIC ACID (1995 AND AFTER ACID AEROSOL...       2900000.0
#
#        LATITUDE  LONGITUDE
# 2930  36.281338 -80.059438
# 2660  36.483300 -79.073100
# 682   35.597500 -80.965800
# 2311  34.372516 -77.859466
# 1610  35.377450 -76.778816
# 2912  36.527800 -78.891700
# 2664  34.746500 -78.806100
# 1310  35.190083 -81.008748
# 1702  35.217222 -81.761111
# 1167  34.283317 -77.985226

# %% [markdown]
# ### Total Toxic Releases 1999 - Top Ten

# %%
topten_byyear[2]['TOTAL_RELEASES'].plot.bar(label='total releases',color='
YDROCHLORIC ACID (1995 AND AFTER ACID AEROSOL...       2400000.0
#
#        LATITUDE  LONGITUDE
# 816   36.483300 -79.073100
# 1609  35.597500 -80.965800
# 1687  36.281338 -80.059438
# 358   36.527800 -78.891700
# 1611  35.190083 -81.008748
# 959   34.746500 -78.806100
# 2651  34.283317 -77.985226
# 2424  35.217222 -81.761111
# 419   35.540928 -78.989750
# 78    35.379910 -78.087688

# %% [markdown]
# ### Total Toxic Releases 2001 - Top Ten

# %%
topten_byyear[4]['TOTAL_RELEASES'].plot.bar(label='total releases',color='#C490D1', legend=None)
mapNClocations(topten_byyear[4].LATITUDE.values,topten_byyear[4].LONGITUDE.values,'Top Releasing TRI Facilities - 2001')
topten_byyear[4]
# Out:
#       YEAR                                      FACILITY_NAME  \
# 728   2001  DUKE ENERGY PROGRESS LLC - ROXBORO STEAM ELECT...
# 1463  2001  DUKE ENERGY CAROLINAS LLC - BELEWS CREEK STEAM...
# 1004  2001  DUKE ENERGY CAROLINAS LLC - MARSHALL STEAM STA...
# 253   2001  DUKE ENERGY PROGRESS LLC-MAYO ELECTRIC GENERAT...
# 2661  2001                                SMITHFIELD-TAR HEEL
# 1393  2001    DUKE ENERGY CAROLINAS LLC - ALLEN STEAM STATION
# 370   2001  DUKE ENERGY PROGRESS LLC - L V SUTTON ENERGY C...
# 2689  2001  DUKE ENERGY CAROLINAS LLC - ROGERS ENERGY COMPLEX
# 151   2001  DUKE ENERGY PROGRESS INC  - CAPE FEAR STEAM EL...
# 2280  2001  DUKE ENERGY PROGRESS LLC - H F LEE ENERGY COMPLEX
#
#                                                CHEMICAL  TOTAL_RELEASES  \
# 728   HYDROCHLORIC ACID (1995 AND AFTER ACID AEROSOL...      18000000.0
# 1463  HYDROCHLORIC ACID (1995 AND AFTER ACID AEROSOL...      11000000.0
# 1004  HYDROCHLORIC ACID (1995 AND AFTER ACID AEROSOL...      10000000.0
# 253   HYDROCHLORIC ACID (1995 AND AFTER ACID AEROSOL...       8300000.0
# 2661                                  NITRATE COMPOUNDS       6288692.0
# 1393  HYDROCHLORIC ACID (1995 AND AFTER ACID AEROSOL...       4600000.0
# 370   HYDROCHLORIC ACID (1995 AND AFTER ACID AEROSOL...       4000000.0
# 2689  HYDROCHLORIC ACID (1995 AND AFTER ACID AEROSOL...       3200000.0
# 151   HYDROCHLORIC ACID (1995 AND AFTER ACID AEROSOL...       2400000.0
# 2280  HYDROCHLORIC ACID (1995 AND AFTER ACID AEROSOL...       2400000.0
#
#        LATITUDE  LONGITUDE
# 728   36.483300 -79.073100
# 1463  36.281338 -80.059438
# 1004  35.597500 -80.965800
# 253   36.527800 -78.891700
# 2661  34.746500 -78.806100
# 1393  35.190083 -81.008748
# 370   34.283317 -77.985226
# 2689  35.217222 -81.761111
# 151   35.540928 -78.989750
# 2280  35.379910 -78.087688

# %% [markdown]
# ### Observations - Top Releasing Facilities - Total
#
# Clearly, something happened between 1997-98, where Duke Energy began to dominate the top emissions. It would be interesting to dig more into why this is. Perhaps Duke didn't report until 1998, those facilities didn't operate before that, or something about their processes changed? It also appears that the total output among the highest releasing facilities skyrocketed around that time.

# %% [markdown]
# ## Top Releasing Facilities - Carcinogens

# %%
carcReleases = [yr[['YEAR','FACILITY_NAME','CHEMICAL','CARCINOGEN','TOTAL_RELEASES','LATITUDE','LONGITUDE']] for yr in nc_data]
topTenCarcinogens = [carcReleases[i][carcReleases[i].CARCINOGEN =='YES'].sort_values('TOTAL_RELEASES',ascending=False)[0:10] for i in range(len(carcReleases))]

# %% [markdown]
# ### Carcinogenic Toxic Releases 1997 - Top Ten

# %%
topTenCarcinogens[0]['TOTAL_RELEASES'].plot.bar(label='total releases',color='#B8336A', legend=None)
mapNClocations(topTenCarcinogens[0].LATITUDE.values,topTenCarcinogens[0].LONGITUDE.values,'Top Carcinogen Releasing TRI Facilities - 1997')
topTenCarcinogens[0]
# Out:
#       YEAR                                      FACILITY_NAME  \
#
['TOTAL_RELEASES'].plot.bar(label='total releases',color='#7D8CC4', legend=None)
mapNClocations(topTenCarcinogens[2].LATITUDE.values,topTenCarcinogens[2].LONGITUDE.values,'Top Carcinogen Releasing TRI Facilities - 1999')
topTenCarcinogens[2]
# Out:
#       YEAR                                      FACILITY_NAME  \
# 791   1999                               OLYMPIC PRODUCTS LLC
# 1763  1999                              ARAUCO PANELS USA LLC
# 1951  1999                 AMERICAN & EFIRD LLC PLANT 05 & 15
# 1071  1999                  INNOCOR FOAM TECHNOLOGIES-ACP INC
# 351   1999  BARNHARDT MANUFACTURING CO NCFI POLYURETHANES DIV
# 2292  1999                                   BATHCRAFT, LLC..
# 2450  1999                              GRADY WHITE BOATS INC
# 2161  1999                                            FXI INC
# 1435  1999                HERITAGE ENVIRONMENTAL SERVICES LLC
# 2220  1999  BLUE RIDGE PAPER PRODUCTS INC (DBA EVERGREEN P...
#
#              CHEMICAL CARCINOGEN  TOTAL_RELEASES   LATITUDE  LONGITUDE
# 791   DICHLOROMETHANE        YES        366920.0  36.006010 -79.780290
# 1763     FORMALDEHYDE        YES        356307.0  35.600670 -79.046340
# 1951  DICHLOROMETHANE        YES        351780.0  35.288218 -81.013597
# 1071  DICHLOROMETHANE        YES        333540.0  35.918580 -79.999670
# 351   DICHLOROMETHANE        YES        332016.0  36.472778 -80.608611
# 2292          STYRENE        YES        325157.0  35.719580 -77.911720
# 2450          STYRENE        YES        275359.0  35.649613 -77.344050
# 2161  DICHLOROMETHANE        YES        239763.0  35.466060 -80.850398
# 1435           NICKEL        YES        189595.0  35.277350 -80.871630
# 2220     ACETALDEHYDE        YES        158900.0  35.535600 -82.841900

# %% [markdown]
# ### Carcinogenic Toxic Releases 2000 - Top Ten

# %%
topTenCarcinogens[3]['TOTAL_RELEASES'].plot.bar(label='total releases',color='#A0D2DB', legend=None)
mapNClocations(topTenCarcinogens[3].LATITUDE.values,topTenCarcinogens[3].LONGITUDE.values,'Top Carcinogen Releasing TRI Facilities - 2000')
topTenCarcinogens[3]
# Out:
#       YEAR                        FACILITY_NAME         CHEMICAL CARCINOGEN  \
# 1572  2000                              FXI INC  DICHLOROMETHANE        YES
# 1045  2000                 OLYMPIC PRODUCTS LLC  DICHLOROMETHANE        YES
# 1409  2000                     BATHCRAFT, LLC..          STYRENE        YES
# 417   2000   AMERICAN & EFIRD LLC PLANT 05 & 15  DICHLOROMETHANE        YES
# 1349  2000    INNOCOR FOAM TECHNOLOGIES-ACP INC  DICHLOROMETHANE        YES
# 2587  2000                ARAUCO PANELS USA LLC     FORMALDEHYDE        YES
# 66    2000  HERITAGE ENVIRONMENTAL SERVICES LLC           NICKEL        YES
# 2123  2000                GRADY WHITE BOATS INC          STYRENE        YES
# 1099  2000              DSM PHARMACEUTICALS INC  DICHLOROMETHANE        YES
# 355   2000                    RSI HOME PRODUCTS          STYRENE        YES
#
#       TOTAL_RELEASES   LATITUDE  LONGITUDE
# 1572        374745.0  35.466060 -80.850398
# 1045        349780.0  36.006010 -79.780290
# 1409        340500.0  35.719580 -77.911720
# 417         328228.0  35.288218 -81.013597
# 1349        314824.0  35.918580 -79.999670
# 2587        309319.0  35.600670 -79.046340
# 66          220635.0  35.277350 -80.871630
# 2123        211618.0  35.649613 -77.344050
# 1099        207997.0  35.659766 -77.358783
# 355         176539.0  35.486943 -81.242500

# %% [markdown]
# ### Carcinogenic Toxic Releases 2001 - Top Ten

# %%
topTenCarcinogens[4]['TOTAL_RELEASES'].plot.bar(label='total releases',color='#C490D1', legend=None)
mapNClocations(topTenCarcinogens[4].LATITUDE.values,topTenCarcinogens[4].LONGITUDE.values,'Top Carcinogen Releasing TRI Facilities - 2001')
topTenCarcinogens[4]
# Out:
#       YEAR                                      FACILITY_NAME  \
# 1796  2001                                   BATHCRAFT, LLC..
# 1956  2001                 AMERICAN & EFIRD LLC PLANT 05 & 15
# 2017  2001                              ARAUCO PANELS USA LLC
# 2259  2001                    DAK AMERICAS LLC CAPE FEAR SITE
# 62    2001                              GRADY WHITE BOATS INC
# 2717  2001                  WIX FILTRATION CORP - ALLEN PLANT
# 450   2001                HERITAGE ENVIRONMENTAL SERVICES LLC
# 243   2001  BLUE RIDGE PAPER PRODUCTS INC (DBA EVERGREEN P...
# 2237  2001                                            FXI INC
# 428   2001                                  RSI HOME PRODUCTS
#
#                         CHEMICAL CARCINOGEN  TOTAL_RELEASES   LATITUDE  \
# 1796                     STYRENE        YES        372700.0  35.719580
# 1956             DICHLOROMETHANE        YES        324248.0  35.288218
# 2017                FORMALDEHYDE        YES        266153.0  35.600670
# 2259            COBALT COMPOUNDS        YES        211296.0  34.322316
# 62                       STYRENE        YES        191158.0  35.649613
# 2717  DI(2-ETHYLHEXYL) PHTHALATE        YES        172650.0  35.276380
# 450                       NICKEL        YES        162830.0  35.277350
# 243                 ACETALDEHYDE        YES        158560.0  35.535600
# 2237             DICHLOROMETHANE        YES        154435.0  35.466060
# 428                      STYRENE        YES        148079.0  35.486943
#
#       LONGITUDE
# 1796 -77.911720
# 1956 -81.013597
# 2017 -79.046340
# 2259 -78.039566
# 62   -77.344050
# 2717 -81.222670
# 450  -80.871630
# 243  -82.841900
# 2237 -80.850398
# 428  -81.242500

# %% [markdown]
# ### Observations - Top Releasing Facilities - Carcinogens
#
# One clear difference in the top carcinogen-releasing facilities as compared to the overall top-releasing facilities is the spead of releases within that group. In the top ten, the release numbers are very close, and generally are large amounts of Dichloromethane. It also appears that, in all of the years, most of the carcinogen-releasing facilities are very close to some large metropolitan areas. Particularly, in 2000 and 2001, there are several high-carcinogen-releasing facilities close to Charlotte.

# %% [markdown]
# # Top Releasing Industry Sectors

# %%
#code, charts and graphs related to top releasing facilities
sectors = [yr[['INDUSTRY_SECTOR', 'CHEMICAL','TOTAL_RELEASES']] for yr in nc_data]
sectors[0].groupby(['INDUSTRY_SECTOR','CHEMICAL']).sum()#.sort_values('TOTAL_RELEASES', ascending=False)
# Out:
#                                                                              TOTAL_RELEASES
# INDUSTRY_SECTOR          CHEMICAL
# Apparel                  AMMONIA                                                     1065.0
#                          CHLORINE                                                       0.0
#                          DIMETHYL PHTHALATE                                           976.0
#                          NAPHTHALENE                                                  157.0
#                          SULFURIC ACID (1994 AND AFTER ACID AEROSOLS" ON...             0.0
# Beverages                AMMONIA                                                   101600.0
#                          CHLORINE                                                       0.0
#                          HYDROCHLORIC ACID (1995 AND AFTER ACID AEROSOLS...         82000.0
#                          NITRATE COMPOUNDS                                          21300.0
#                          PHOSPHORIC ACID                                                0.0
# Chemical Wholesalers     CERTAIN GLYCOL ETHERS                                          0.0
#                          CHLORINE                                                     161.0
# Chemicals                1,1-DICHLORO-1-FLUOROETHANE                                29326.0
#                          1,2,4-TRICHLOROBENZENE                                         0.0
#                          1,2,4-TRIMETHYLBENZENE                                     20845.0
#                          1,2-DICHLOROETHANE                                          5102.0
#                          1,3-BUTADIENE                                               5080.0
#                          1,3-PHENYLENEDIAMINE                                           0.0
#                          1,4-DICHLOROBENZENE                                         7893.0
#                          1,4-DIOXANE                                                54406.0
#                          2,4-DIAMINOTOLUENE                                             0.0
#                          2-METHOXYETHANOL                                             102.0
#                          2-PHENYLPHENOL                                                 0.0
#                          3,3'-DIMETHOXYBENZIDINE DIHYDROCHLORIDE                        0.0
#                          4,4'-ISOPROPYLIDENEDIPHENOL                                  318.0
#                          4,4'-METHYLENEDIANILINE                                        0.0
#                          4-AMINOAZOBENZENE                                              0.0
#                          ACETALDEHYDE                                              881913.0
#                          ACETONITRILE                                                4356.0
#                          ACETOPHENONE                                                   0.0
# ...                                                                                     ...
# Transportation Equipment TOLUENE-2,4-DIISOCYANATE                                       0.0
#                          XYLENE (MIXED ISOMERS)                                     56546.0
#                          ZINC (FUME OR DUST)                                        27615.0
#                          ZINC COMPOUNDS                                             20878.0
# Wood Products            ACETALDEHYDE                                              152459.0
#                          ACROLEIN                                                   36000.0
#                          AMMONIA                                                    10910.0
#                          ANTHRACENE                                                     5.0
#                          ARSENIC                                                        0.0
#                          ARSENIC COMPOUNDS                                           3299.0
#                          BARIUM COMPOUNDS                                            6111.0
#                          CERTAIN GLYCOL ETHERS                                      12000.0
#                          CHROMIUM                                                       0.0
#                          CHROMIUM COMPOUNDS(EXCEPT CHROMITE ORE MINED IN...          2481.0
#                          COPPER COMPOUNDS                                            1593.0
#                          CRESOL (MIXED ISOMERS)                                     26860.0
#                          DIBENZOFURAN                                                 255.0
#                          DIISOCYANATES                                                 71.0
#                          FORMALDEHYDE                                              508840.0
#                          METHANOL                                                  585703.0
#                          METHYL ETHYL KETONE                                        82549.0
#                          N-BUTYL ALCOHOL                                            38457.0
#                          NAPHTHALENE                                                  500.0
#                          NITRATE COMPOUNDS                                          23590.0
#                          PENTACHLOROPHENOL                                              2.0
#                          PHENOL                                                    164370.0
#                          PHOSPHORIC ACID                                                0.0
#                          SULFURIC ACID (1994 AND AFTER ACID AEROSOLS" ON...             0.0
#                          TOLUENE                                                    56834.0
#                          VINYL ACETATE                                               2415.0
#
# [712 rows x 1 columns]

# %% [markdown]
# ## Basemap Visualization

# %%
#code and Basemap visualizations
