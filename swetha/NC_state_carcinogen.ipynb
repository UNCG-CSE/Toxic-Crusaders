# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data_tri_2015 = pd.read_csv('TRI_2015_NC.csv')
data_tri_2014 = pd.read_csv('TRI_2014_NC.csv')
data_tri_2013 = pd.read_csv('TRI_2013_NC.csv')
data_tri_2012 = pd.read_csv('TRI_2012_NC.csv')

# %%
data_tri_2015[data_tri_2015.duplicated('TRI_FACILITY_ID')].sort_values('TRI_FACILITY_ID', ascending = 0)
#TRI_FACILITY_ID.nunique()
# Out:
#       YEAR  TRI_FACILITY_ID        FRS_ID  \
# 2015  2015  28904CLMNC788TU  1.100100e+11
# 1088  2015  28813SCHWTHWY19  1.100190e+11
# 1972  2015  2880WSTHRN8PNDR  1.100540e+11
# 2171  2015  2880WDVSTL4MEAD  1.100040e+11
# 1581  2015  2880WDVSTL4MEAD  1.100040e+11
# 706   2015  2880WDVSTL4MEAD  1.100040e+11
# 1789  2015  28804RVCSC275AI  1.100090e+11
# 2080  2015  28804RVCSC275AI  1.100090e+11
# 2079  2015  28804RVCSC275AI  1.100090e+11
# 1175  2015  28804RVCSC275AI  1.100090e+11
# 1617  2015  28804RVCSC275AI  1.100090e+11
# 2029  2015  28804RVCSC275AI  1.100090e+11
# 590   2015  28804RVCSC275AI  1.100090e+11
# 1883  2015  28804RVCSC275AI  1.100090e+11
# 614   2015  28804RVCSC275AI  1.100090e+11
# 242   2015  28804RVCSC275AI  1.100090e+11
# 2183  2015  28803STHRN35MEA  1.100310e+11
# 245   2015  28803NSNNG41SWE  1.100040e+11
# 1086  2015  28803NSNNG41SWE  1.100040e+11
# 221   2015  28792SLCRP700SH  1.100000e+11
# 71    2015  28792SLCRP700SH  1.100000e+11
# ...

# %%
list (data_tri_2015.groupby(['TRI_FACILITY_ID','CARCINOGEN']))
# Out:
# [(('27008STHRNHWY70', 'NO'),
#         YEAR  TRI_FACILITY_ID        FRS_ID              FACILITY_NAME  \
#   508   2015  27008STHRNHWY70  1.100000e+11  SOUTHERN STATES FEED MILL
#   1001  2015  27008STHRNHWY70  1.100000e+11  SOUTHERN STATES FEED MILL
#
#                STREET_ADDRESS       CITY COUNTY  ST    ZIP  BIA_CODE  \
#   508   9150 STATESVILLE BLVD  CLEVELAND  ROWAN  NC  27013       NaN
#   1001  9150 STATESVILLE BLVD  CLEVELAND  ROWAN  NC  27013       NaN
#
#                   ...            8.4_RECYCLING_ON-SITE   8.5_RECYCLING_OFF-SITE  \
#   508             ...                              0.0                      0.0
#   1001            ...                              0.0                      0.0
#
#         8.6_TREATMENT_ON-SITE 8.7_TREATMENT_OFF-SITE  \
#   508                     0.0                    0.0
#   1001                    0.0                    0.0
#
#         PROD._WASTE_(8.1_THRU_8.7) 8.8_ONE-TIME_RELEASE  PROD_RATIO_OR_ACTIVITY  \
# ...

# %%
list (group_facilityid_carcinogen)

# %%
data_tri_2015_carcinogen = data_tri_2015[data_tri_2015['CARCINOGEN']== 'YES']

# %%
data_tri_2014_carcinogen = data_tri_2014[data_tri_2014['CARCINOGEN']== 'YES']

# %%
group_facilityid_2015_carcinogen = data_tri_2015_carcinogen.groupby(['TRI_FACILITY_ID'])

# %%
group_facilityid_2014_carcinogen = data_tri_2014_carcinogen.groupby(['TRI_FACILITY_ID'])

# %%
data_tri_2015_carcinogen['ALLCHEMICAL_ON-SITE_RELEASE_TOTAL'] = group_facilityid_2015_carcinogen['ON-SITE_RELEASE_TOTAL'].transform('sum')
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
data_tri_2014_carcinogen['ALLCHEMICAL_ON-SITE_RELEASE_TOTAL'] = group_facilityid_2014_carcinogen['ON-SITE_RELEASE_TOTAL'].transform('sum')
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
data_tri_2015_carcinogen
# Out:
#       YEAR  TRI_FACILITY_ID        FRS_ID  \
# 1     2015  2803WBRLCM5CRRE  1.100460e+11
# 2     2015  28111TLDYN2020A  1.100000e+11
# 5     2015  28456FDRLPRIEGE  1.100100e+11
# 11    2015  28080THTMK1TIMK  1.100100e+11
# 19    2015  27374MRSNN325WE  1.100070e+11
# 20    2015  27835HNDRX1101I  1.100020e+11
# 22    2015  27849PRDNCHIGHW  1.100040e+11
# 23    2015  28384SPXVL1491N  1.100160e+11
# 25    2015  27856PRDFRALTUS  1.100100e+11
# 33    2015  27320BHMFLROUTE  1.100100e+11
# 34    2015  27320BHMFLROUTE  1.100100e+11
# 40    2015  28139RVSBRRAILR  1.100010e+11
# 41    2015  28655SGLCR307JA  1.100020e+11
# 43    2015  27260THMSB1408C  1.100000e+11
# 49    2015  2740WSSCTD1SUTH  1.100460e+11
# 50    2015  2833WHNSNP451WE  1.100390e+11
# 51    2015  28792SLCRP700SH  1.100000e+11
# 53    2015  27886KHNCR4047M  1.100130e+11
# 58    2015  27894LJRPL510EA  1.100100e+11
# 63    2015  27028NGRSL501SA  1.100000e+11
# 64    2015  2789WBLCKC252WI  1.100440e+11
# ...

# %%
data_tri_2014_carcinogen
# Out:
#       YEAR  TRI_FACILITY_ID        FRS_ID  \
# 2     2014  28206CNCRT3823R  110001479775
# 7     2014  27834MTLLX251IN  110015308111
# 8     2014  28054WLSHC207TE  110041964201
# 13    2014  2808WCNCRT11HLI  110044314391
# 23    2014  28758BRNFRPOBOX  110018548124
# 25    2014  27886KHNCR4047M  110012707419
# 30    2014  2740WSSCTD1SUTH  110046278997
# 31    2014  27420GLBRC7300F  110000847601
# 33    2014  27030NRTHC511CA  110000345172
# 34    2014  28120GSTNCHWY27  110004015789
# 35    2014  2811WTLLVC375AL  110018570688
# 43    2014  28012DKNRG253PL  110000348008
# 44    2014  27209FNDRY530EM  110000345573
# 46    2014  28732TNCRPCANEC  110000740690
# 52    2014  27042HLSTDHWY31  110009844865
# 53    2014  27957RJRYNSTATE  110042039692
# 56    2014  27374MRSNN325WE  110006722029
# 58    2014  27203PRSTG2206D  110000345528
# 62    2014  2811WTLLVC375AL  110018570688
# 67    2014  28401STRDY1822C  110015583778
# 68    2014  28115GNRLM1133N  110006424752
# ...

# %%
data_tri_2015_carcinogen.drop_duplicates(['TRI_FACILITY_ID'], keep='last',inplace=True)
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
data_tri_2014_carcinogen.drop_duplicates(['TRI_FACILITY_ID'], keep='last',inplace=True)
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %% [markdown]
# #The industry sector that is causing the release of most carcinogenic on site release is shown below -- for the year 2015

# %%
data_tri_2015_carcinogen[data_tri_2015_carcinogen['ALLCHEMICAL_ON-SITE_RELEASE_TOTAL']==data_tri_2015_carcinogen['ALLCHEMICAL_ON-SITE_RELEASE_TOTAL'].max()]['INDUSTRY_SECTOR']
# Out:
# 2308    Wood Products
# Name: INDUSTRY_SECTOR, dtype: object

# %%
grouped_min_carcinogen_2015  = data_tri_2015_carcinogen[data_tri_2015_carcinogen['ALLCHEMICAL_ON-SITE_RELEASE_TOTAL']==data_tri_2015_carcinogen['ALLCHEMICAL_ON-SITE_RELEASE_TOTAL'].min()].groupby('INDUSTRY_SECTOR').size()

# %%
grouped_min_carcinogen_2014  = data_tri_2014_carcinogen[data_tri_2014_carcinogen['ALLCHEMICAL_ON-SITE_RELEASE_TOTAL']==data_tri_2014_carcinogen['ALLCHEMICAL_ON-SITE_RELEASE_TOTAL'].min()].groupby('INDUSTRY_SECTOR').size()

# %%
grouped_min_carcinogen_2015
# Out:
# INDUSTRY_SECTOR
# Chemical Wholesalers                  3
# Chemicals                            10
# Computers and Electronic Products     3
# Electrical Equipment                 10
# Fabricated Metals                    19
# Food                                  4
# Hazardous Waste                       4
# Machinery                             9
# Metal Mining                          1
# Miscellaneous Manufacturing           1
# Nonmetallic Mineral Product           2
# Other                                 2
# Paper                                 1
# Petroleum                             1
# Petroleum Bulk Terminals              5
# Plastics and Rubber                   2
# Primary Metals                        5
# Textile Product                       2
# Textiles                              1
# Tobacco                               1
# Transportation Equipment             11
# Wood Products                         2
# dtype: int64

# %%
grouped_min_carcinogen_2014
# Out:
# INDUSTRY_SECTOR
# Chemical Wholesalers                  5
# Chemicals                             9
# Computers and Electronic Products     4
# Electrical Equipment                  9
# Fabricated Metals                    19
# Food                                  5
# Hazardous Waste                       4
# Machinery                            10
# Miscellaneous Manufacturing           1
# Nonmetallic Mineral Product           3
# Other                                 2
# Petroleum                             1
# Petroleum Bulk Terminals              5
# Plastics and Rubber                   2
# Primary Metals                        5
# Textile Product                       2
# Textiles                              1
# Tobacco                               2
# Transportation Equipment             10
# Wood Products                         5
# dtype: int64

# %%
grouped_min_carcinogen =

# %%
grouped_min_carcinogen_2015.where(grouped_min_carcinogen_2015 == grouped_min_carcinogen_2015.max()).dropna()
# Out:
# INDUSTRY_SECTOR
# Fabricated Metals    19.0
# dtype: float64

# %%
grouped_min_carcinogen_2014.where(grouped_min_carcinogen_2014 == grouped_min_carcinogen_2014.max()).dropna()
# Out:
# INDUSTRY_SECTOR
# Fabricated Metals    19.0
# dtype: float64

# %% [markdown]
# #The industry sector that is causing the release of most carcinogenic on site release is shown below -- for the year 2014

# %%
data_tri_2014_carcinogen[data_tri_2014_carcinogen['ALLCHEMICAL_ON-SITE_RELEASE_TOTAL']==data_tri_2014_carcinogen['ALLCHEMICAL_ON-SITE_RELEASE_TOTAL'].max()]['INDUSTRY_SECTOR']
# Out:
# 1610    Wood Products
# Name: INDUSTRY_SECTOR, dtype: object

# %%
data_merged_carcinogen = pd.merge(data_tri_2015_carcinogen,data_tri_2014_carcinogen,how = 'inner',on ='TRI_FACILITY_ID' )

# %%
data_merged_carcinogen.sort_values('TRI_FACILITY_ID',ascending = 0)
# Out:
#      YEAR_x  TRI_FACILITY_ID      FRS_ID_x  \
# 181    2015  28906SXTLS250SN  1.100150e+11
# 52     2015  28906CLFTNHWY14  1.100450e+11
# 126    2015  28813SCHWTHWY19  1.100190e+11
# 304    2015  2880WDVSTL4MEAD  1.100040e+11
# 175    2015  2880WDMSNL19MEA  1.100650e+11
# 133    2015  28806BRGWR31ADA  1.100310e+11
# 267    2015  28804RVCSC275AI  1.100090e+11
# 125    2015  28803NSNNG41SWE  1.100040e+11
# 297    2015  28792SLCRP700SH  1.100000e+11
# 212    2015  28787RLNCLREEMS  1.100000e+11
# 250    2015  28787BLCRN1BALC  1.100010e+11
# 177    2015  28779JCKSNPOSTO  1.100010e+11
# 43     2015  28777MCSPR1025G  1.100120e+11
# 168    2015  28762PNVLLHIGHW  1.100160e+11
# 328    2015  28758BRNFRPOBOX  1.100190e+11
# 203    2015  28752DDGRC100RO  1.100000e+11
# 200    2015  28752BXTRHHWY22  1.100190e+11
# 242    2015  28739GNRLL3010S  1.100000e+11
# 20     2015  28739BLDNGHIGHW  1.100080e+11
# 311    2015  28734CRNDSPODRA  1.100000e+11
# 274    2015  28732TNCRPCANEC  1.100010e+11
# ...

# %%
data_merged_carcinogen[(data_merged_carcinogen['YEAR_x']==2015) ][1:100].plot(x= 'TRI_FACILITY_ID',y='ALLCHEMICAL_ON-SITE_RELEASE_TOTAL_x',kind = 'line')

# %%
data_merged_carcinogen[(data_merged_carcinogen['YEAR_y']==2014)][1:100].plot(x= 'TRI_FACILITY_ID',y='ALLCHEMICAL_ON-SITE_RELEASE_TOTAL_y',kind = 'line' )

# %%
#plt.pie(x,labels=data_tri_2014_carcinogen['TRI_FACILITY_ID'][1:20],autopct='%1.1f%%')
